# %% [markdown]
# # Парсинг страниц Auto.ru

# %%
import pandas as pd
import numpy as np
from scipy import stats
from matplotlib import pyplot as plt
from sklearn import preprocessing
import seaborn

# %% [markdown]
# ## Сбор данных: парсинг и выделение признаков
# С помощью скрипта autoru_parser.py мы можем выделить следующие признаки для каждого объявления:
# 1. Вещественные:
#     - Рубли/Доллары/Евро
#     - Пробег
# 2. Целочисленные:
#     - Количество дверей
#     - Объем багажника
#     - Количество владельцев
#     - Координаты
#     - Регион (по кодам)
#     - Год
# 3. Категориальные (в т.ч. бинарные):
#     - Лицензия - бинарный (True, False)
#     - Авто класс - бинарный (True/False)
#     - С салона - бинарный (True, False)
#     - Таможня - бинарный (True, False)
#     - PTS - (Dublicate, Original)
#     - Доступность - In_Stock, Out_Of_Stock
#     - Категория (для конкретной выборки Mersedes - cars)
#     - Цвет (в виде кода, можно преобразовать в более общие категории, а не по точным оттенкам)
#     - Временная зона
#     - Тип автомобиля
#     - Марка автомобиля
#     - Модель автомобиля
#
#
# 4. Другие:
#     - Описание
#     - Фото/изображения
#     - Имя автомобиля - строковый/категориальный
#     - VIN - индивидуальный шифр

# %%
with open('autoru_parsing_result2.txt', 'r') as file:
    lines = file.readlines()

# Uncomment to see lines:
# lines
# Out:
# ['Лицензия: ******|18\n',
#  'Доступность: IN_STOCK\n',
#  'Категория: cars\n',
#  'Цвет: #040001\n',
#  'Описание: MERCEDES-BENZ S350 4MATIC LONG\n',
#  '\n',
#  'Рестайлинг! AMG пакет!\n',
#  '\n',
#  'Бензиновый двигатель 3.5 л. 272 л.с. Коробка автомат, постоянный полный привод. Удлиненная база.\n',
#  '\n',
#  'Сборка Германия.\n',
#  'Покупался и обслуживался у официального дилера.\n',
#  'Автомобиль в отличном состоянии полностью обслужен, никаких вложений не требует, никаких ошибок нет! За последнее время много всего сделано.\n',
#  'Родной пробег 164 тыс.км.\n',
#  '\n',
#  'Юридически чист. Не в залоге не в кредите никаких обременений на авто нет!\n',
#  'Выпуск по ПТС 2010 год. 2 комплекта ключей.\n',
#  '\n',
#  'В ДТП не участвовал, вин скину по запросу. \n',
#  '\n',
#  'Автомобиль находится в Ижевске, осмотр в любое время.\n',
#  '\n',
#  'Обратите внимание на комплектацию:\n',
#  'AMG пакет\n',
#  'Доводчики дверей\n',
#  'Пневмоподвеска\n',
#  'Навигация\n',
#  'Телевидение, DVD чейнджер\n',
#  'Климат контроль четырехзонный\n',
#  'Вентиляция передних и задних сидений\n',
#  'Подогрев передних и задних сидений\n',
#  'Автоматическое переключение света (ближний/дальний)\n',
#  'Панорамная крыша, электролюк\n',
#  'Электропривод и обогрев руля\n',
#  'Электропривод передних и задних сидений с памятью\n',
#  'Мониторы в подголовниках передних сидений\n',
#  'и многое другое!\n',
#  '\n',
#  'Возможен торг. \n',
#  'Рассмотрю обмен на ваш авто с доплатой в любую сторону.\n',
#  'Таможня: True\n',
#  'Количество владельцев: 4\n',
#  'PTS: DUPLICATE\n',
#  'VIN: WDD**************\n',
#  'Vin разрешение: OK\n',
#  'Год: 2010\n',
#  'Рубли: 1360000\n',
#  'Евро: 15929\n',
#  'Доллар: 18182\n',
#  'С салона: False\n',
#  'Координаты: 56.852592:53.204842\n',
#  'Регион: Ижевск\n',
#  'Временная зона: +04\n',
#  'Пробег: 174000\n',
#  'Тип автомобиля: SEDAN\n',
#  'Количество дверей: 4\n',
#  'Not class auto\n',
#  'Имя автомобиля: Седан Long\n',
#  'Not trunk volume min\n',
#  'Марка автомобиля: Mercedes-Benz\n',
#  'Модель автомобиля: S-Класс\n',
#  'Информация: 3.0d\xa0AT (258\xa0л.с.), седан, задний, дизель\n',
#  '//avatars.mds.yandex.net/get-autoru-vos/5859003/5a36ac0800965b2d3d6a88792a7f6ac0/1200x900\n',
#  '//avatars.mds.yandex.net/get-autoru-vos/5965445/128fcc92e768eff7b4c6a25b72f35d3c/1200x900\n',
#  '//avatars.mds.yandex.net/get-autoru-vos/6078333/61516602746228eda2bb1b4d892ebafc/1200x900\n',
#  '//avatars.mds.yandex.net/get-autoru-vos/6087763/ad04f09b63480e5d11c4d417f71ed889/1200x900\n',
#  '//avatars.mds.yandex.net/get-autoru-vos/5527432/c6a7772d26783e443255538944cc0497/1200x900\n',
#  '//avatars.mds.yandex.net/get-autoru-vos/5859826/52b10c791d9bb3c893737bee5b475364/1200x900\n',
#  '//avatars.mds.yandex.net/get-autoru-vos/5490388/7f02365bac05947099fc4fbafaf7e318/1200x900\n',
#  '//avatars.mds.yandex.net/get-autoru-vos/5966122/1d0a329ea30659223df04661f018597a/1200x900\n',
#  '//avatars.mds.yandex.net/get-autoru-vos/6109589/c5850b5f806a4631624fd2e71e0e396a/1200x900\n',
#  '//avatars.mds.yandex.net/get-autoru-vos/5519299/f5d4df0d455455e8a5b86bac897b2860/1200x900\n',
#  '//avatars.mds.yandex.net/get-autoru-vos/5859003/bc1c876a3fdeedc042143555d92023af/1200x900\n',
#  '\n',
#  '=================================================================================================================================\n',
#  'Лицензия: ******|716\n',
#  'Доступность: IN_STOCK\n',
#  'Категория: cars\n',
#  'Цвет: #97948F\n',
#  'Описание: Состояние нового\n',
#  'Расширенный пакет аэродинамических элементов \n',
#  'Мультибим свет\n',
#  'Цвет матовый - оригинальный, не пленка. \n',
#  'ТО раз в 5-7 тысяч у дилера\n',
#  'Панорама \n',
#  'Торг\n',
#  'Таможня: True\n',
#  'Количество владельцев: 1\n',
#  'PTS: ORIGINAL\n',
#  'VIN: WDD**************\n',
#  'Vin разрешение: OK\n',
#  'Год: 2019\n',
#  'Рубли: 4310000\n',
#  'Евро: 50482\n',
#  'Доллар: 57619\n',
#  'С салона: False\n',
#  'Координаты: 55.796288:49.108795\n',
#  'Регион: Казань\n',
#  'Временная зона: MSK\n',
#  'Пробег: 28000\n',
#  'Тип автомобиля: SEDAN\n',
#  'Количество дверей: 4\n',
#  'Not class auto\n',
#  'Имя автомобиля: Седан\n',
#  'Not trunk volume min\n',
#  'Марка автомобиля: Mercedes-Benz\n',
#  'Модель автомобиля: A-Класс AMG\n',
#  'Информация: 2.0\xa0AMT (306\xa0л.с.), седан, полный, бензин\n',
#  '//avatars.mds.yandex.net/get-autoru-vos/5859003/5a36ac0800965b2d3d6a88792a7f6ac0/1200x900\n',
#  '//avatars.mds.yandex.net/get-autoru-vos/5965445/128fcc92e768eff7b4c6a25b72f35d3c/1200x900\n',
#  '//avatars.mds.yandex.net/get-autoru-vos/6078333/61516602746228eda2bb1b4d892ebafc/1200x900\n',
#  '//avatars.mds.yandex.net/get-autoru-vos/6087763/ad04f09b63480e5d11c4d417f71ed889/1200x900\n',
#  '//avatars.mds.yandex.net/get-autoru-vos/5527432/c6a7772d26783e443255538944cc0497/1200x900\n',
#  '//avatars.mds.yandex.net/get-autoru-vos/5859826/52b10c791d9bb3c893737bee5b475364/1200x900\n',
#  '//avatars.mds.yandex.net/get-autoru-vos/5490388/7f02365bac05947099fc4fbafaf7e318/1200x900\n',
#  '//avatars.mds.yandex.net/get-autoru-vos/5966122/1d0a329ea30659223df04661f018597a/1200x900\n',
#  '//avatars.mds.yandex.net/get-autoru-vos/6109589/c5850b5f806a4631624fd2e71e0e396a/1200x900\n',
#  '//avatars.mds.yandex.net/get-autoru-vos/5519299/f5d4df0d455455e8a5b86bac897b2860/1200x900\n',
#  '//avatars.mds.yandex.net/get-autoru-vos/5859003/bc1c876a3fdeedc042143555d92023af/1200x900\n',
#  '//avatars.mds.yandex.net/get-autoru-vos/6054061/66c3a0da966414b98fcd552ee0a2d010/1200x900\n',
#  '//avatars.mds.yandex.net/get-autoru-vos/6001602/0b3369e9e4544497ac673fe4fb7efea6/1200x900\n',
#  '//avatars.mds.yandex.net/get-autoru-vos/6109589/cd7f24f34297b832e3818a9eb0257b21/1200x900\n',
#  '//avatars.mds.yandex.net/get-autoru-vos/5930866/7fbe1a080266380ab56c9e11db5337ea/1200x900\n',
#  '//avatars.mds.yandex.net/get-autoru-vos/5454639/ca1ce89f5ee4e196fb0ceef6f4ce954b/1200x900\n',
#  '//avatars.mds.yandex.net/get-autoru-vos/6076405/bf2d75aaf17df3141cbeb41383118c1d/1200x900\n',
#  '//avatars.mds.yandex.net/get-autoru-vos/5479518/9fe51f0bb8d0b51d49769fe97516fe85/1200x900\n',
#  '//avatars.mds.yandex.net/get-autoru-vos/4968723/8b3406fa13c2c709cf12f803a1814778/1200x900\n',
#  '//avatars.mds.yandex.net/get-autoru-vos/6001602/9647de29a050fcc43adf8f835da835f3/1200x900\n',
#  '//avatars.mds.yandex.net/get-autoru-vos/5519772/1339e971fd515dd567b2a3a60c6b535b/1200x900\n',
#  '//avatars.mds.yandex.net/get-autoru-vos/5966918/62f38d487c561a68d8eefb47699b5c42/1200x900\n',
#  '\n',
#  '=================================================================================================================================\n',
#  'Лицензия: ******|716\n',
#  'Доступность: IN_STOCK\n',
#  'Категория: cars\n',
#  'Цвет: #FAFBFB\n',
#  'Описание: Продам Мерседес GLE 300 d . Автомобиль в идеальном состоянии , не битый , не крашеный 100%. Любые проверки за ваш счёт . Зимняя резина мишлен на дисках. Установлен съёмный фаркоп. \n',
#  'Таможня: True\n',
#  'Количество владельцев: 1\n',
#  'PTS: ORIGINAL\n',
#  'VIN: W1N**************\n',
#  'Vin разрешение: OK\n',
#  'Год: 2020\n',
#  'Рубли: 7120000\n',
#  'Евро: 83394\n',
#  'Доллар: 95185\n',
#  'С салона: False\n',
#  'Координаты: 55.743584:52.395874\n',
#  'Регион: Набережные Челны\n',
#  'Временная зона: MSK\n',
#  'Пробег: 15000\n',
#  'Тип автомобиля: ALLROAD_5_DOORS\n',
#  'Количество дверей: 5\n',
#  'Not class auto\n',
#  'Имя автомобиля: Внедорожник 5 дв.\n',
#  'Not trunk volume min\n',
#  'Марка автомобиля: Mercedes-Benz\n',
#  'Модель автомобиля
/1200x900\n',
#  '//avatars.mds.yandex.net/get-autoru-vos/5869876/52550813a266cf383d75c3be6fc2f5f5/1200x900\n',
#  '//avatars.mds.yandex.net/get-autoru-vos/4612068/28ed245d2f4b2ec70b4c8b689824d52a/1200x900\n',
#  '//avatars.mds.yandex.net/get-autoru-vos/5859826/5c95bf0a5a4fc6054cc19d3a721c6329/1200x900\n',
#  '//avatars.mds.yandex.net/get-autoru-vos/4824178/b856fdb702d3a66c0cb3d60cfb5f79b2/1200x900\n',
#  '//avatars.mds.yandex.net/get-autoru-vos/4612068/2d7eba4a31052c28ff24b93d32517d36/1200x900\n',
#  '//avatars.mds.yandex.net/get-autoru-vos/5859529/98f5b4db42d03caa8c5e3bdf32d7763e/1200x900\n',
#  '//avatars.mds.yandex.net/get-autoru-vos/5966918/cbb8a874780853758718f3b4caf83838/1200x900\n',
#  '//avatars.mds.yandex.net/get-autoru-vos/5497741/ee1297d58fb5e8b0058cf56537258074/1200x900\n',
#  '//avatars.mds.yandex.net/get-autoru-vos/5869876/6fe8a776e9014112c0fcf53e3becac90/1200x900\n',
#  '//avatars.mds.yandex.net/get-autoru-vos/5484094/ee97c2d72ef702fb75f4c7c88a797d3c/1200x900\n',
#  '//avatars.mds.yandex.net/get-autoru-vos/4612068/f130e63072c229da657d187f66951880/1200x900\n',
#  '//avatars.mds.yandex.net/get-autoru-vos/5489899/f5805d1208aa5d3e10b6b8a514ac5fcf/1200x900\n',
#  '//avatars.mds.yandex.net/get-autoru-vos/5478026/d37372b6a524e2b5bc99d8a5165efb14/1200x900\n',
#  '\n',
#  '=================================================================================================================================\n',
#  'Not license plate \n',
#  'Доступность: IN_STOCK\n',
#  'Категория: cars\n',
#  'Цвет: #0000CC\n',
#  'Описание: Оформи кредит онлайн без справок!\n',
#  '\n',
#  'Гарантия на автомобиль от автосалона\n',
#  ' \n',
#  'Все самое интересное в инстаграмм autosalon_stolica\n',
#  '\n',
#  'Авто проверен и готов к эксплуатации!\n',
#  '\n',
#  'Закажи видеообзор, специально для вас на WhatsApp, Viber\n',
#  'VIN: WDD2383661F033792 Mercedes-Benz E400 в отличном состоянии! ПТС оригинал! Прошивка STAGE-2 Morendi 455 л.с. (По ПТС 333 л.с.)! Полсностью в родном окрасе!\n',
#  '\n',
#  'В комплектацию входит: \n',
#  '- 8 подушек безопасности\n',
#  '- Передние и задние электростеклоподъемники\n',
#  '- Система контроля слепых зон\n',
#  '- Парктроник передний и задний\n',
#  '- Антиблокировочная система (ABS)\n',
#  '- Система курсовой стабилизации (ESP) \n',
#  '- Доводчики дверей\n',
#  '- Система контроля усталости водителя\n',
#  '- Система старт-стоп\n',
#  '- Система доступа без ключа\n',
#  '- Контроль давления в шинах\n',
#  '- Адаптивная оптика\n',
#  '- Полностью обклеен бронепленкой\n',
#  '- Система комплекской помощи при торможении\n',
#  '- Панораманная крыша \n',
#  '- Вентиляция и подогрев сидений\n',
#  '- Память сидений и электрорегулировка\n',
#  '- Премиальная аудиосистема MBUX\n',
#  '- Подача ремня безопасности при посадке\n',
#  '- Беспроводная зарядка смартфона\n',
#  '----------------\n',
#  'Онлайн: Возможность выбрать и оплатить автомобиль без визита в салон!\n',
#  '----------------\n',
#  'Trade-in: Вы можете сдать свой автомобиль в замен на новый!\n',
#  '----------------\n',
#  'Страхование: Оформляем ОСАГО, КАСКО!\n',
#  '----------------\n',
#  'Тест-драйв: Прокатитесь на своем будущем автомобиле!\n',
#  'Таможня: True\n',
#  'Количество владельцев: 3\n',
#  'PTS: ORIGINAL\n',
#  'VIN: WDD**************\n',
#  'Vin разрешение: OK\n',
#  'Год: 2017\n',
#  'Рубли: 4620000\n',
#  'Евро: 54111\n',
#  'Доллар: 61763\n',
#  'С салона: False\n',
#  'Координаты: 56.876049:53.170071\n',
#  'Регион: Ижевск\n',
#  'Временная зона: +04\n',
#  'Пробег: 67000\n',
#  'Тип автомобиля: COUPE\n',
#  'Количество дверей: 2\n',
#  'Класс автомобиля: E\n',
#  'Имя автомобиля: Купе\n',
#  'Объем багажника: 425\n',
#  'Марка автомобиля: Mercedes-Benz\n',
#  'Модель автомобиля: E-Класс\n',
#  'Информация: 3.0\xa0AT (333\xa0л.с.), купе, полный, бензин\n',
#  '//avatars.mds.yandex.net/get-autoru-vos/5859003/5a36ac0800965b2d3d6a88792a7f6ac0/1200x900\n',
#  '//avatars.mds.yandex.net/get-autoru-vos/5965445
#  '\n',
#  '\n',
#  'Автосалон подержанных автомобилей " CARWAY" (Адрес: Московское шоссе 262 «В» пересечение улиц Московское шоссе/Губанова в районе бывшего Ипподрома ) предлагает комплекс услуг по выкупу и продаже автомобилей:\n',
#  'На автомобиль распространяется техническая гарантия - 1 год от KARSO.\n',
#  ...]

# %% [markdown]
# Пока не будем никак работать с изображениями, поэтому уберем их:

# %%
prefix = '//avatars.' # to remove unnececcasy images for now
newlines = [x for x in lines if not x.startswith(prefix)]

# Uncomment to see lines without image links:
# newlines
# Out:
# ['Лицензия: ******|18\n',
#  'Доступность: IN_STOCK\n',
#  'Категория: cars\n',
#  'Цвет: #040001\n',
#  'Описание: MERCEDES-BENZ S350 4MATIC LONG\n',
#  '\n',
#  'Рестайлинг! AMG пакет!\n',
#  '\n',
#  'Бензиновый двигатель 3.5 л. 272 л.с. Коробка автомат, постоянный полный привод. Удлиненная база.\n',
#  '\n',
#  'Сборка Германия.\n',
#  'Покупался и обслуживался у официального дилера.\n',
#  'Автомобиль в отличном состоянии полностью обслужен, никаких вложений не требует, никаких ошибок нет! За последнее время много всего сделано.\n',
#  'Родной пробег 164 тыс.км.\n',
#  '\n',
#  'Юридически чист. Не в залоге не в кредите никаких обременений на авто нет!\n',
#  'Выпуск по ПТС 2010 год. 2 комплекта ключей.\n',
#  '\n',
#  'В ДТП не участвовал, вин скину по запросу. \n',
#  '\n',
#  'Автомобиль находится в Ижевске, осмотр в любое время.\n',
#  '\n',
#  'Обратите внимание на комплектацию:\n',
#  'AMG пакет\n',
#  'Доводчики дверей\n',
#  'Пневмоподвеска\n',
#  'Навигация\n',
#  'Телевидение, DVD чейнджер\n',
#  'Климат контроль четырехзонный\n',
#  'Вентиляция передних и задних сидений\n',
#  'Подогрев передних и задних сидений\n',
#  'Автоматическое переключение света (ближний/дальний)\n',
#  'Панорамная крыша, электролюк\n',
#  'Электропривод и обогрев руля\n',
#  'Электропривод передних и задних сидений с памятью\n',
#  'Мониторы в подголовниках передних сидений\n',
#  'и многое другое!\n',
#  '\n',
#  'Возможен торг. \n',
#  'Рассмотрю обмен на ваш авто с доплатой в любую сторону.\n',
#  'Таможня: True\n',
#  'Количество владельцев: 4\n',
#  'PTS: DUPLICATE\n',
#  'VIN: WDD**************\n',
#  'Vin разрешение: OK\n',
#  'Год: 2010\n',
#  'Рубли: 1360000\n',
#  'Евро: 15929\n',
#  'Доллар: 18182\n',
#  'С салона: False\n',
#  'Координаты: 56.852592:53.204842\n',
#  'Регион: Ижевск\n',
#  'Временная зона: +04\n',
#  'Пробег: 174000\n',
#  'Тип автомобиля: SEDAN\n',
#  'Количество дверей: 4\n',
#  'Not class auto\n',
#  'Имя автомобиля: Седан Long\n',
#  'Not trunk volume min\n',
#  'Марка автомобиля: Mercedes-Benz\n',
#  'Модель автомобиля: S-Класс\n',
#  'Информация: 3.0d\xa0AT (258\xa0л.с.), седан, задний, дизель\n',
#  '\n',
#  '=================================================================================================================================\n',
#  'Лицензия: ******|716\n',
#  'Доступность: IN_STOCK\n',
#  'Категория: cars\n',
#  'Цвет: #97948F\n',
#  'Описание: Состояние нового\n',
#  'Расширенный пакет аэродинамических элементов \n',
#  'Мультибим свет\n',
#  'Цвет матовый - оригинальный, не пленка. \n',
#  'ТО раз в 5-7 тысяч у дилера\n',
#  'Панорама \n',
#  'Торг\n',
#  'Таможня: True\n',
#  'Количество владельцев: 1\n',
#  'PTS: ORIGINAL\n',
#  'VIN: WDD**************\n',
#  'Vin разрешение: OK\n',
#  'Год: 2019\n',
#  'Рубли: 4310000\n',
#  'Евро: 50482\n',
#  'Доллар: 57619\n',
#  'С салона: False\n',
#  'Координаты: 55.796288:49.108795\n',
#  'Регион: Казань\n',
#  'Временная зона: MSK\n',
#  'Пробег: 28000\n',
#  'Тип автомобиля: SEDAN\n',
#  'Количество дверей: 4\n',
#  'Not class auto\n',
#  'Имя автомобиля: Седан\n',
#  'Not trunk volume min\n',
#  'Марка автомобиля: Mercedes-Benz\n',
#  'Модель автомобиля: A-Класс AMG\n',
#  'Информация: 2.0\xa0AMT (306\xa0л.с.), седан, полный, бензин\n',
#  '\n',
#  '=================================================================================================================================\n',
#  'Лицензия: ******|716\n',
#  'Доступность: IN_STOCK\n',
#  'Категория: cars\n',
#  'Цвет: #FAFBFB\n',
#  'Описание: Продам Мерседес GLE 300 d . Автомобиль в идеальном состоянии , не битый , не крашеный 100%. Любые проверки за ваш счёт . Зимняя резина мишлен на дисках. Установлен съёмный фаркоп. \n',
#  'Таможня: True\n',
#  'Количество владельцев: 1\n',
#  'PTS: ORIGINAL\n',
#  'VIN: W1N**************\n',
#  'Vin разрешение: OK\n',
#  'Год: 2020\n',
#  'Рубли: 7120000\n',
#  'Евро: 83394\n',
#  'Доллар: 95185\n',
#  'С салона: False\n',
#  'Координаты: 55.743584:52.395874\n',
#  'Регион: Набережные Челны\n',
#  'Временная зона: MSK\n',
#  'Пробег: 15000\n',
#  'Тип автомобиля: ALLROAD_5_DOORS\n',
#  'Количество дверей: 5\n',
#  'Not class auto\n',
#  'Имя автомобиля: Внедорожник 5 дв.\n',
#  'Not trunk volume min\n',
#  'Марка автомобиля: Mercedes-Benz\n',
#  'Модель автомобиля: GLE\n',
#  'Информация: 2.9d\xa0AT (272\xa0л.с.), внедорожник, полный, дизель\n',
#  '\n',
#  '=================================================================================================================================\n',
#  'Лицензия: ******|156\n',
#  'Доступность: IN_STOCK\n',
#  'Категория: cars\n',
#  'Цвет: #040001\n',
#  'Описание: Машина в хорошем состоянии. Эксплуатация с 2012 года. Полный привод. На новой зимней резине.\n',
#  'Таможня: True\n',
#  'Количество владельцев: 4\n',
#  'PTS: DUPLICATE\n',
#  'VIN: WDD**************\n',
#  'Vin разрешение: OK\n',
#  'Год: 2011\n',
#  'Рубли: 1520000\n',
#  'Евро: 17803\n',
#  'Доллар: 20320\n',
#  'С салона: False\n',
#  'Координаты: 55.796288:49.108795\n',
#  'Регион: Казань\n',
#  'Временная зона: MSK\n',
#  'Пробег: 137000\n',
#  'Тип автомобиля: SEDAN\n',
#  'Количество дверей: 4\n',
#  'Not class auto\n',
#  'Имя автомобиля: Седан\n',
#  'Not trunk volume min\n',
#  'Марка автомобиля: Mercedes-Benz\n',
#  'Модель автомобиля: E-Класс\n',
#  'Информация: 3.5\xa0AT (306\xa0л.с.), седан, полный, бензин\n',
#  '\n',
#  '=================================================================================================================================\n',
#  'Not license plate \n',
#  'Доступность: IN_STOCK\n',
#  'Категория: cars\n',
#  'Цвет: #040001\n',
#  'Описание: Временная скидка - 31000₽\n',
#  'Чёткий черный Мерседес всего за 349000₽ действует до 11.02.2022 г. \n',
#  'Без ГБО ещё 6000₽ скидка.\n',
#  '1.8л. С 200 компрессор, 163 л.с.\n',
#  'На авто установлено ГБО.\n',
#  'Вся обслужена. \n',
#  'Всегда обслуживается.\n',
#  'Кап.ремонт двигателя на 296000км. с заменой цепи.\n',
#  'Полная замена масла в АКПП 31 декабря 2021 года.\n',
#  '\n',
#  '\n',
#  'Таможня: True\n',
#  'Количество владельцев: 4\n',
#  'PTS: DUPLICATE\n',
#  'VIN: WDB**************\n',
#  'Vin разрешение: OK\n',
#  'Год: 2003\n',
#  'Рубли: 380000\n',
#  'Евро: 4451\n',
#  'Доллар: 5080\n',
#  'С салона: False\n',
#  'Координаты: 54.905762:52.29705\n',
#  'Регион: Альметьевск\n',
#  'Временная зона: MSK\n',
#  'Пробег: 375000\n',
#  'Тип автомобиля: SEDAN\n',
#  'Количество дверей: 4\n',
#  'Not class auto\n',
#  'Имя автомобиля: Седан\n',
#  'Not trunk volume min\n',
#  'Марка автомобиля: Mercedes-Benz\n',
#  'Модель автомобиля: C-Класс\n',
#  'Информация: 2.0\xa0AT (163\xa0л.с.), седан, задний, бензин\n',
#  '\n',
#  '=================================================================================================================================\n',
#  'Not license plate \n',
#  'Доступность: IN_STOCK\n',
#  'Категория: cars\n',
#  'Цвет: #040001\n',
#  'Описание: Продажа от официального дилера Volvo Car Горки г. Казань. Автомобиль куплен у официального дилера в 2010 г. Автомобиль в отличном техническом состоянии.\n',
#  'Готовы ответить на все Ваши вопросы каждый день с 8 до 20.\n',
#  'ПРЕИМУЩЕСТВА:\n',
#  '• Автомобиль прошел полную техническую диагностику\n',
#  '• Гарантия юридической чистоты\n',
#  '• У нас есть Кредитные программы\n',
#  '• Есть возможность оформить автомобиль в лизинг\n',
#  '• Возможность приобрести автомобиль в кредит БЕЗ ПЕРВОНАЧАЛЬНОГО ВЗНОСА\n',
#  '• Все виды страхования (КАСКО, ОСАГО и прочее)\n',
#  '• Услуга Автопобор за наш счет\n',
#  'Примем в зачет Ваш автомобиль на автомобиль с пробегом (обмен с доплатой в обе стороны) Специальное предложение при условии обмена (TRADE-IN) :\n',
#  '* Единовременная скидка до 100 000 рублей на автомобиль с пробегом Место осмотра:\n',
#  'Осмотреть автомобиль можно по адресу: Казань, ул. Родины, д. 1в\n',
#  'Таможня: True\n',
#  'Количество владельцев: 4\n',
#  'PTS: ORIGINAL\n',
#  'VIN: WDD**************\n',
#  'Vin разрешение: OK\n',
#  'Год: 2010\n',
#  'Рубли: 1220000\n',
#  'Евро: 14290\n',
#  'Доллар: 16309\n',
#  'С салона: True\n',
#  'Координаты: 55.761299:49.193642\n',
#  'Регион: Казань\n',
#  'Временная зона: MSK\n',
#  'Пробег: 199000\n',
#  'Тип автомобиля: SEDAN\n',
#  'Количество дверей: 4\n',
#  'Not class auto\n',
#  'Имя автомобиля: Седан\n',
#  'Not trunk volume min\n',
#  'Марка автомобиля: Mercedes-Benz\n',
#  'Модель автомобиля: S-Класс\n',
#  'Информация: 5.5\xa0AT (388\xa0л.с.), седан, полный, бензин\n',
#  '\n',
#  '=================================================================================================================================\n',
#  'Лицензия: ******|199\n',
#  'Доступность: IN_STOCK\n',
#  'Категория: cars\n',
#  'Цвет: #97948F\n',
#  'Not description\n',
#  'Таможня: True\n',
#  'Количество владельцев: 3\n',
#  'PTS: ORIGINAL\n',
#  'VIN: WDD**************\n',
#  'Not vin resolution \n',
#  'Год: 2005\n',
#  'Рубли: 880000\n',
#  'Евро: 10307\n',
#  'Доллар: 11764\n',
#  'С салона: False\n',
#  'Координаты: 54.316856:48.402557\n',
#  'Регион: Ульяновск\n',
#  'Временная зона: +04\n',
#  'Пробег: 195000\n',
#  'Тип автомобиля: SEDAN\n',
#  'Количество дверей: 4\n',
#  'Not class auto\n',
#  'Имя автомобиля: Седан Long\n',
#  'Not trunk volume min\n',
#  'Марка автомобиля: Mercedes-Benz\n',
#  'Модель автомобиля: S-Класс\n',
#  'Информация: 5.5\xa0AT (517\xa0л.с.), седан, задний, бензин\n',
#  '\n',
#  '=================================================================================================================================\n',
#  'Not license plate \n',
#  'Доступность: IN_STOCK\n',
#  'Категория: cars\n',
#  'Цвет: #040001\n',
#  'Описание: Автомобиль куплен в мае 2021 года. На гарантии! Кузов полностью в заводском ЛКП, в ДТП не участвовала. По факту 1 хозяин. Передняя часть и зоны риска оклеены в полиуретановую пленку. Имеется летний комплект шин. \n',
#  'Богатая комплектация: Кожа Nappa, панорамная крыша, подвеска AMG RIDE CONTROL+, камеры кругового обзора, 3-местное заднее сиденье, автодоводчики дверей, пакет функций Keyless-Go, диски AMG 20 радиуса.\n',
#  'Более подробную информацию уточняйте по телефону.\n',
#  'Автомобиль продается АВТОСАЛОНОМ "Легион-Авто" - Продажа новых автомобилей ПРЕМИУМ-КЛАССА - Обмен на ваш автомобиль (trade-in); - Гарантии юридической чистоты автомобиля и сделки; - В нашем автосалоне вы можете воспользоваться финансовыми сервисами: Кредитование: Более 15 банков партнеров Необходимые документы: ПАСПОРТ и ВОДИТЕЛЬСКОЕ УДОСТОВЕРЕНИЕ! - Обращайтесь в «ЛегионАвто», и мы сможем подобрать для вас надежное транспортное средство с пробегом и без по низкой стоимости и на лучших условиях!\n',
#  '- ИНДИВИДУАЛЬНЫЙ ПОДХОД К КАЖДОМУ КЛИЕНТУ !\n',
#  '- МЫ НАХОДИМСЯ ПО АДРЕСУ: г. КАЗАНЬ, ул. ОСТРОВСКОГО, д. 22.\n',
#  'Таможня: True\n',
#  'Количество владельцев: 2\n',
#  'PTS: ORIGINAL\n',
#  'VIN: W1K**************\n',
#  'Vin разрешение: OK\n',
#  'Год: 2020\n',
#  'Рубли: 11690000\n',
#  'Евро: 136920\n',
#  'Доллар: 156280\n',
#  'С салона: False\n',
#  'Координаты: 55.793903:49.149506\n',
#  'Регион: Казань\n',
#  'Временная зона: MSK\n',
#  'Пробег: 8000\n',
#  'Тип автомобиля: LIFTBACK\n',
#  'Количество дверей: 5\n',
#  'Not class auto\n',
#  'Имя автомобиля: Лифтбек\n',
#  'Not trunk volume min\n',
#  'Марка автомобиля: Mercedes-Benz\n',
#  'Модель автомобиля: AMG GT\n',
#  'Информация: 3.0\xa0AMT (367\xa0л.с.), лифтбек, полный, бензин\n',
#  '\n',
#  '=================================================================================================================================\n',
#  'Not license plate \n',
#  'Доступность: IN_STOCK\n',
#  'Категория: cars\n',
#  'Цвет: #0000CC\n',
#  'Описание: Автомобиль продается от официального дилерского центра РРТ Автомаркет\n',
#  '\n',
#  'Преимущества:\n',
#  '· 1 владелец\n',
#  '· ПТС оригинал\n',
#  '· Отличное техническое состояние\n',
#  '· Автомобиль прошел полную техническую диагностику\n',
#  '· Сервисная книжка с отметками о прохождении планового обслуживания\n',
#  '\n',
#  'Дополнительно установлено:\n',
#  '· Защита картера\n',
#  '· Тонировка\n',
#  '· Ковры салона\n',
#  '· Парктроник\n',
#  '\n',
#  '***********************************************************************************\n',
#  'РРТ-Автомаркет - крупнейший Центр продаж автомобилей с пробегом в городе Казань. Мы осуществляем продажи, обмен и выкуп автомобилей с пробегом.\n',
#  ' \n',
#  'Победитель Национальной премии "АВТОДИЛЕР ГОДА, 2021" в области организации продаж автомобилей с пробегом.\n',
#  ' \n',
#  'Предлагаем только самые выгодные и надежные решения для наших клиентов:\n',
#  '1.  Более 300 проверенных автомобилей с пробегом на одной площадке.\n',
#  '2.  Оформим сделку одним днем с абсолютной юридической чистотой.\n',
#  '3.  Предоставим все виды автокредитования! У нас: 14 надежных банков-партнеров, оформление без первоначального взноса, одобрение день в день.\n',
#  '4.  Любые услуги по страхованию автомобилей.\n',
#  '5.  Примем ваш автомобиль в зачет любого выбранного автомобиля по системе Trade-in.\n',
#  '6.  Срочный выкуп вашего автомобиля за 1 час и деньги сразу.\n',
#  'Выкупаем любой автомобиль, в любом состоянии, в том числе и кредитный. Приедем к вам сами.\n',
#  '7.  РРТ-Аукцион. Открытая и честная площадка. Более 120 автомобилей с пробегом ежедневно! Открытая автотека, ПТС, видео, личный менеджер, доставка в любой регион!  Доставка в любой регион России. (без СНГ)\n',
#  'Таможня: True\n',
#  'Количество владельцев: 1\n',
#  'PTS: ORIGINAL\n',
#  'VIN: Z9M**************\n',
#  'Vin разрешение: OK\n',
#  'Год: 2019\n',
#  'Рубли: 4210000\n',
#  'Евро: 49310\n',
#  'Доллар: 56282\n',
#  'С салона: False\n',
#  'Координаты: 55.835304:49.142483\n',
#  'Регион: Казань\n',
#  'Временная зона: MSK\n',
#  'Пробег: 27000\n',
#  'Тип автомобиля: SEDAN\n',
#  'Количество дверей: 4\n',
#  'Not class auto\n',
#  'Имя автомобиля: Седан\n',
#  'Not trunk volume min\n',
#  'Марка автомобиля: Mercedes-Benz\n',
#  'Модель автомобиля: E-Класс\n',
#  'Информация: 3.0\xa0AT (333\xa0л.с.), седан, полный, бензин\n',
#  '\n',
#  '=================================================================================================================================\n',
#  'Not license plate \n',
#  'Доступность: IN_STOCK\n',
#  'Категория: cars\n',
#  'Цвет: #0000CC\n',
#  'Описание: Оформи кредит онлайн без справок!\n',
#  '\n',
#  'Гарантия на автомобиль от автосалона\n',
#  ' \n',
#  'Все самое интересное в инстаграмм autosalon_stolica\n',
#  '\n',
#  'Авто проверен и готов к эксплуатации!\n',
#  '\n',
#  'Закажи видеообзор, специально для вас на WhatsApp, Viber\n',
#  'VIN: WDD2383661F033792 Mercedes-Benz E400 в отличном состоянии! ПТС оригинал! Прошивка STAGE-2 Morendi 455 л.с. (По ПТС 333 л.с.)! Полсностью в родном окрасе!\n',
#  '\n',
#  'В комплектацию входит: \n',
#  '- 8 подушек безопасности\n',
#  '- Передние и задние электростеклоподъемники\n',
#  '- Система контроля слепых зон\n',
#  '- Парктроник передний и задний\n',
#  '- Антиблокировочная система (ABS)\n',
#  '- Система курсовой стабилизации (ESP) \n',
#  '- Доводчики дверей\n',
#  '- Система контроля усталости водителя\n',
#  '- Система старт-стоп\n',
#  '- Система доступа без ключа\n',
#  '- Контроль давления в шинах\n',
#  '- Адаптивная оптика\n',
#  '- Полностью обклеен бронепленкой\n',
#  '- Система комплекской помощи при торможении\n',
#  '- Панораманная крыша \n',
#  '- Вентиляция и подогрев сидений\n',
#  '- Память сидений и электрорегулировка\n',
#  '- Премиальная аудиосистема MBUX\n',
#  '- Подача ремня безопасности при посадке\n',
#  '- Беспроводная зарядка смартфона\n',
#  '----------------\n',
#  'Онлайн: Возможность выбрать и оплатить автомобиль без визита в салон!\n',
#  '----------------\n',
#  'Trade-in: Вы можете сдать свой автомобиль в замен на новый!\n',
#  '----------------\n',
#  'Страхование: Оформляем ОСАГО, КАСКО!\n',
#  '----------------\n',
#  'Тест-драйв: Прокатитесь на своем будущем автомобиле!\n',
#  'Таможня: True\n',
#  'Количество владельцев: 3\n',
#  'PTS: ORIGINAL\n',
#  'VIN: WDD**************\n',
#  'Vin разрешение: OK\n',
#  'Год: 2017\n',
#  'Рубли: 4620000\n',
#  'Евро: 54111\n',
#  'Доллар: 61763\n',
#  'С салона: False\n',
#  'Координаты: 56.876049:53.170071\n',
#  'Регион: Ижевск\n',
#  'Временная зона: +04\n',
#  'Пробег: 67000\n',
#  'Тип автомобиля: COUPE\n',
#  'Количество дверей: 2\n',
#  'Класс автомобиля: E\n',
#  'Имя автомобиля: Купе\n',
#  'Объем багажника: 425\n',
#  'Марка автомобиля: Mercedes-Benz\n',
#  'Модель автомобиля: E-Класс\n',
#  'Информация: 3.0\xa0AT (333\xa0л.с.), купе, полный, бензин\n',
#  '\n',
#  '=================================================================================================================================\n',
#  'Not license plate \n',
#  'Доступность: IN_STOCK\n',
#  'Категория: cars\n',
#  'Цвет: #FAFBFB\n',
#  'Описание: MERCEDES-BENZ: Продается автомобиль автомобиль в безупречном состоянии. Без аварий и ДТП. Кузов в родном окрасе. На автомобиле пройдено техническое обслуживание. Все стекла родные. ПТС оригинал. Богатая комплектация: электропривод и память сидений, аудиосистема премиум класса Harman/Kardon, электропривод двери багажника, бесключевой доступ в автомобиль, обогрев руля, обогрев всех сидений включая задние, электропривод рулевой колонки, парктроники, климат-контроль на три зоны, камера заднего вида, навигационная система, подрулевые лепестки, предпусковой обогреватель, изменяемый клиренс, пневмоподвеска, круиз-контроль, запуск двигателя с кнопки. Очень бережная эксплуатация. Вложений автомобиль не требует. Любые проверки. \n',
#  '\n',
#  '\n',
#  'Автосалон подержанных автомобилей " CARWAY" (Адрес: Московское шоссе 262 «В» пересечение улиц Московское шоссе/Губанова в районе бывшего Ипподрома ) предлагает комплекс услуг по выкупу и продаже автомобилей:\n',
#  'На автомобиль распространяется техническая гарантия - 1 год от KARSO.\n',
#  'Данный автомобиль возможно приобрести с гарантией KARSO. В техническую гарантию входит 48 основных узлов агрегатов автомобиля, в том числе: Двигатель, коробка передач, редуктор и прочие узлы и агрегаты. С полным перечнем можно ознакомиться на сайте гарантийной компании KARSO.\n',
#  '1. Срочный ВЫКУП автомобилей за 30 минут!\n',
#  '2. Мы принимаем автомобили, на комиссию - Быстро, Удобно - Максимально выгодно для Ваc!\n',
#  '3.АВТОКРЕДИТОВАНИЕ. Мы продаем автомобили в КРЕДИТ. Сотрудничаем со всеми основными банками в сфере автокредитования. Более 16 банков в одном месте. Возможно оформление кредита автомобилей со стороны.\n',
#  '4. Мы сотрудничаем со всеми основными и проверенными страховыми компаниями. Быстро и с полагающимися скидками оформим ОСАГО и КАСКО.\n',
#  '5. Мы предлагаем услугу "On-line комиссия" суть которой заключается в размещении Вашего автомобиля в нашей базе, на сайте и активной рекламе на всех популярных автомобильных изданиях в сети интернет. Мы продаем как - будто Ваш автомобиль стоит у нас на стоянке, но на самом деле Вы пользуетесь им. Для многих это окажется очень удобно. МЫ ГАРАНТИРУЕМ БЫСТРУЮ ПРОДАЖУ!\n',
#  '6. TRADE IN. Мы предлагаем выгодный и удобный обмен автомобилями. Рассматриваем любые варианты, с Вашей или нашей доплатой, равноценно. У НАС САМЫЙ ВЫГОДНЫЙ ОБМЕН НА ЛЮБЫЕ НОВЫЕ АВТОМОБИЛИ!!!\n',
#  '7. Комиссионная продажа автомобиля от 2 %, это услуга подойдет тем, кто хочет продать автомобиль быстро и по рыночной цене. Гарантируем бережное отношение, сохранность и быструю продажу.\n',
#  '\n',
#  'Таможня: True\n',
#  'Количество владельцев: 2\n',
#  'PTS: ORIGINAL\n',
#  'VIN: WDC**************\n',
#  'Vin разрешение: OK\n',
#  'Год: 2013\n',
#  'Рубли: 3030000\n',
#  'Евро: 35489\n',
#  'Доллар: 40507\n',
#  'С салона: False\n',
#  'Координаты: 53.248978:50.216732\n',
#  'Регион: Самара\n',
#  'Временная зона: +04\n',
#  'Пробег: 126000\n',
#  'Тип автомобиля: ALLROAD_5_DOORS\n',
#  'Количество дверей: 5\n',
#  'Not class auto\n',
#  'Имя автомобиля: Внедорожник 5 дв.\n',
#  'Not trunk volume min\n',
#  'Марка автомобиля: Mercedes-Benz\n',
#  'Модель автомобиля: M-Класс\n',
#  'Информация: 3.0d\xa0AT (225\xa0л.с.), внедорожник, полный, дизель\n',
#  '\n',
#  '=================================================================================================================================\n',
#  'Not license plate \n',
#  'Доступность: IN_STOCK\n',
#  'Категория: cars\n',
#  'Цвет: #CACECB\n',
#  'Описание: Мерседес с200 купе w203, cl203, роботизированная КПП, новое сцепление.\n',
#  '\n',
#  'Техническое состояние  - ОТЛИЧНОЕ!!!\n',
#  '\n',
#  'Это предложение для настоящих Мерсиан. Только для ценителей.\n',
#  '\n',
#  'Сам собственник!\n',
#  '\n',
#  'Зимняя резина липучка 2020 года.\n',
#  '\n',
#  'Автомобиль обслуживается, не требует вложений!\n',
#  '\n',
#  'Кузов красивый, ровный.\n',
#  'Салон в шикарном состоянии.\n',
#  '\n',
#  'Хорошее техническое состояние. Мотор 111 - бессмертный😉\n',
#  '\n',
#  'В подарок гос номер 131 16 рус.\n',
#  '\n',
#  'ТРИАВТО ТRIАVТО - советуют друзьям.\n',
#  '\n',
#  'Принимаем автомобили по вашей цене.\n',
#  '\n',
#  'скорее звони и приезжай.\n',
#  '\n',
#  'подпишись INSТАGRАМ @АLВЕRТ_ТRIАVТO\n',
#  'Таможня: True\n',
#  'Количество владельцев: 4\n',
#  'PTS: DUPLICATE\n',
#  'VIN: WDB**************\n',
#  'Vin разрешение: OK\n',
#  'Год: 2001\n',
#  'Рубли: 490000\n',
#  'Евро: 5740\n',
#  'Доллар: 6550\n',
#  'С салона: False\n',
#  'Координаты: 54.905762:52.29705\n',
#  'Регион: Альметьевск\n',
#  'Временная зона: MSK\n',
#  'Пробег: 318000\n',
#  'Тип автомобиля: HATCHBACK_3_DOORS\n',
#  'Количество дверей: 3\n',
#  'Not class auto\n',
#  'Имя автомобиля: Хэтчбек 3 дв.\n',
#  'Not trunk volume min\n',
#  'Марка автомобиля: Mercedes-Benz\n',
#  'Модель автомобиля: C-Класс\n',
#  'Информация: 1.8\xa0AMT (192\xa0л.с.), хэтчбек 3 дв., задний, бензин\n',
#  '\n',
#  '=================================================================================================================================\n',
#  'Лицензия: ******|163\n',
#  'Доступность: IN_STOCK\n',
#  'Категория: cars\n',
#  'Цвет: #FAFBFB\n',
#  'Описание: Пробег 125 тыс, весь  в заводском окрасе, полностью обслужен, Диски и колодки вкруг заменены, новая летняя резина, шумка. Макс комплектация( Музыка bang, расширенная отделка кожей, все ассистенты, круговой обзор, автозапуск, подогрев, вентиляция, массаж, зима на 21 дисках) Проверка только у дилера. Обмен на E63 w213, с моей доплатой. Зима на 21-ых. \n',
#  'Таможня: True\n',
#  'Количество владельцев: 3\n',
#  'PTS: ORIGINAL\n',
#  'VIN: WDC**************\n',
#  'Vin разрешение: OK\n',
#  'Год: 2015\n',
#  'Рубли: 4790000\n',
#  'Евро: 56103\n',
#  'Доллар: 64036\n',
#  'С салона: False\n',
#  'Координаты: 53.195538:50.101784\n',
#  'Регион: Самара\n',
#  'Временная зона: +04\n',
#  'Пробег: 120000\n',
#  'Тип автомобиля: ALLROAD_5_DOORS\n',
#  'Количество дверей: 5\n',
#  'Класс автомобиля: J\n',
#  'Имя автомобиля: Внедорожник 5 дв.\n',
#  'Объем багажника: 650\n',
#  'Марка автомобиля: Mercedes-Benz\n',
#  'Модель автомобиля: GLE Coupe AMG\n',
#  'Информация: 5.5\xa0AT (558\xa0л.с.), внедорожник, полный, бензин\n',
#  '\n',
#  '=================================================================================================================================\n',
#  'Лицензия: ******|77\n',
#  'Доступность: IN_STOCK\n',
#  'Категория: cars\n',
#  'Цвет: #040001\n',
#  'Описание: Один владелец, физ лицо. В ДТП не учавствовал.\n',
#  'Искусственная кожа АРТИКО / микроволокно\n',
#  'ДИНАМИКА - Черный цвет (601)\n',
#  '\n',
#  ' Дополнительное оборудование:\n',
#  '23P Пакет вспомогательных систем (адаптивный круиз-контроль) \n',
#  '489 Пакет AIRMATIC (пневма) \n',
#  '543 Двойной солнцезащитный козырек \n',
#  '810 Акустическая система объемного звучания Burmester 1\n',
#  '883 Сервозакрывание дверей \n',
#  'P47 Пакет систем помощи при парковке с системой камер\n',
#  'кругового обзора\n',
#  '\n',
#  'P55 Пакет Night \n',
#  'U47 Кромка-спойлер AMG\n',
#  'Таможня: True\n',
#  'Количество владельцев: 1\n',
#  'PTS: ORIGINAL\n',
#  'VIN: W1N**************\n',
#  'Vin разрешение: OK\n',
#  'Год: 2021\n',
#  'Рубли: 9360000\n',
#  'Евро: 109630\n',
#  'Доллар: 125131\n',
#  'С салона: False\n',
#  'Координаты: 55.796288:49.108795\n',
#  'Регион: Казань\n',
#  'Временная зона: MSK\n',
#  'Пробег: 5000\n',
#  'Тип автомобиля: ALLROAD_5_DOORS\n',
#  'Количество дверей: 5\n',
#  'Класс автомобиля: J\n',
#  'Имя автомобиля: Внедорожник 5 дв.\n',
#  'Объем багажника: 655\n',
#  'Марка автомобиля: Mercedes-Benz\n',
#  'Модель автомобиля: GLE Coupe\n',
#  'Информация: 2.9d\xa0AT (249\xa0л.с.), внедорожник, полный, дизель\n',
#  '\n',
#  '=================================================================================================================================\n',
#  'Лицензия: ******|21\n',
#  'Доступность: IN_STOCK\n',
#  'Категория: cars\n',
#  'Цвет: #040001\n',
#  'Описание: Продаю Mercedes-Benz Е 200 \n',
#  'Владею 3 год , Пробег 💯% оригинальный,любые проверки!\n',
#  'На машине нет не одной страховой выплаты!!!\n',
#  'Оригинальный AMG пакет , чёрный потолок ,AMG пакет салона , сам паркуется , и многое другое !Я являюсь 5 владельцем, все остальные записи были \n',
#  'Автосалоны , смена номеров.и юр лица. Машина находится в идеальном техническом и внешнем состоянии. Мотор 274, самый надежный, масло не расходует ни грамму. Менялось строго \n',
#  '4500-5000 км, заливалось  только оригинальное. Цепь, звезды поменял на 190 тыс км.  Мотор и коробка в  идеальном состоянии , любые проверки. Ни одной ошибки по электронике. Ходовая без лишних стуков и нареканий.\n',
#  '2 комплекта резины как новые, откатали 3 тыс км. По вашему желанию заедем в любой тех.центр для проверки авто. Есть сервисная книга. На машину денег не жалел, ставил все оригинальное!\n',
#  'Торг разумный  приветствуется !\n',
#  'Таможня: True\n',
#  'Количество владельцев: 4\n',
#  'PTS: DUPLICATE\n',
#  'VIN: WDD**************\n',
#  'Vin разрешение: OK\n',
#  'Год: 2013\n',
#  'Not price rub\n',
#  'Not price eur\n',
#  'Not price usd\n',
#  'С салона: False\n',
#  'Координаты: 56.146278:47.25108\n',
#  'Регион: Чебоксары\n',
#  'Временная зона: MSK\n',
#  'Пробег: 235000\n',
#  'Тип автомобиля: SEDAN\n',
#  'Количество дверей: 4\n',
#  'Not class auto\n',
#  'Имя автомобиля: Седан\n',
#  'Not trunk volume min\n',
#  'Марка автомобиля: Mercedes-Benz\n',
#  'Модель автомобиля: E-Класс\n',
#  'Информация: 2.1d\xa0MT (170\xa0л.с.), седан, задний, дизель\n',
#  '\n',
#  '=================================================================================================================================\n',
#  'Not license plate \n',
#  'Доступность: IN_STOCK\n',
#  'Категория: cars\n',
#  'Цвет: #CACECB\n',
#  'Описание: Ваш автомобиль уже заждался вас. Звоните прямо сейчас!\n',
#  '\n',
#  'Автомобиль прошёл комплексную диагностику.\n',
#  '\n',
#  'Юридически проверен — не в розыске, не в угоне, не в залоге, не в\n',
#  'кредите, свободен от штрафов. Готов к осмотру и тест-драйву!\n',
#  '\n',
#  'Гарантируем, что мы не скручиваем пробег!\n',
#  '\n',
#  'Все сделки юридически прозрачны и подкреплены договором.\n',
#  '\n',
#  'Хотите больше выбора? Добро пожаловать в «Авторай-ЭКСПЕРТ»: более 600* авто с пробегом самых разных марок ждут вас, новые поступления каждый день — принимаем ежедневно до 10 свежих авто!\n',
#  '\n',
#  'ООО «Авторай-ЭКСПЕРТ» — эксперты по всем вопросам подержанных\n',
#  'автомобилей. У нас можно: купить автомобиль, продать автомобиль,\n',
#  'получить профессиональную консультацию по любым вопросам покупки или продажи автомобиля.\n',
#  '\n',
#  'Ваш автомобиль уже заждался вас. Звоните прямо сейчас!\n',
#  'Не забудьте нажать на ❤️, чтобы добавить объявление в Избранное и следить за изменением цены.\n',
#  '\n',
#  '*По состоянию на 1 января 2022 года.\n',
#  '**Количество собственников в технических характеристиках объявления указывается согласно данных ГИБДД и соответствуют количеству собственников, ставивших автомобиль на учет.\n',
#  '\n',
#  '#cmecMTIxMi1XREMyMDQ5ODQxRzIxMDk2NV9SRC0wMDk1Mw==\n',
#  'Таможня: True\n',
#  'Количество владельцев: 2\n',
#  'PTS: ORIGINAL\n',
#  'VIN: WDC**************\n',
#  'Vin разрешение: OK\n',
#  'Год: 2013\n',
#  'Рубли: 2210000\n',
#  'Евро: 25885\n',
#  'Доллар: 29545\n',
#  'С салона: False\n',
#  'Координаты: 54.291008:48.263947\n',
#  'Регион: Ульяновск\n',
#  'Временная зона: +04\n',
#  'Пробег: 102000\n',
#  'Тип автомобиля: ALLROAD_5_DOORS\n',
#  'Количество дверей: 5\n',
#  'Not class auto\n',
#  'Имя автомобиля: Внедорожник 5 дв.\n',
#  'Not trunk volume min\n',
#  'Марка автомобиля: Mercedes-Benz\n',
#  'Модель автомобиля: GLK-Класс\n',
#  'Информация: 2.1d\xa0AT (170\xa0л.с.), внедорожник, полный, дизель\n',
#  '\n',
#  '=================================================================================================================================\n',
#  'Лицензия: ******|763\n',
#  'Доступность: IN_STOCK\n',
#  'Категория: cars\n',
#  'Цвет: #97948F\n',
#  'Описание: Полностью обслуженный авто. Беспроводная зарядка. Вентиляция сидений. Ассистент экстренного торможения. Автоматическая парковка . Электропривод багажника , открытие без ключа. Доводчики , комфортный доступ .Зимняя резина новая.\n',
#  'Машина отполированная + 4 слоя керамики . Приезжайте смотрите машина в достойном состоянии \n',
#  'Таможня: True\n',
#  'Количество владельцев: 2\n',
#  'PTS: DUPLICATE\n',
#  'VIN: WDD**************\n',
#  'Vin разрешение: OK\n',
#  'Год: 2018\n',
#  'Рубли: 6100000\n',
#  'Евро: 71446\n',
#  'Доллар: 81550\n',
#  'С салона: False\n',
#  'Координаты: 53.195538:50.101784\n',
#  'Регион: Самара\n',
#  'Временная зона: +04\n',
#  'Пробег: 101000\n',
#  'Тип автомобиля: SEDAN\n',
#  'Количество дверей: 4\n',
#  'Not class auto\n',
#  'Имя автомобиля: Седан\n',
#  'Not trunk volume min\n',
#  'Марка автомобиля: Mercedes-Benz\n',
#  'Модель автомобиля: CLS\n',
#  'Информация: 2.9d\xa0AT (286\xa0л.с.), седан, полный, дизель\n',
#  '\n',
#  '=================================================================================================================================\n',
#  'Not license plate \n',
#  'Доступность: IN_STOCK\n',
#  'Категория: cars\n',
#  'Цвет: #040001\n',
#  'Описание: Надежный автомобиль с бережными собственниками.\n',
#  'Автомобиль вовремя обслуживался. Расходники менялись.\n',
#  'Автоматическая коробка передач.\n',
#  'Передний привод.\n',
#  'Двигатель и КПП прошли комплексную диагностику\n',
#  'Чистый и опрятный салон.\n',
#  'Зимняя резина на литых дисках.\n',
#  'Комплектация:\n',
#  '- Центральный замок\n',
#  '- Мультимедиа\n',
#  '- Гидроусилитель руля\n',
#  '- И многое другое\n',
#  'Автомобиль на 100% юридически чистый, прошел все проверки и готов к эксплуатации. Возможен обмен на ваш автомобиль.\n',
#  '\n',
#  '---------------------------------------------------------\n',
#  '🚖 АЛЬЯНС SELECT – крупнейшая площадка автомобилей с пробегом в Чувашской Республике. Более 800 автомобилей от официальных дилеров в наличии! 🚐 🚙 🚗\n',
#  '---------------------------------------------------------\n',
#  '🎥 Закажите видеообзор автомобиля специально для Вас на WhatsApp, Viber.\n',
#  '---------------------------------------------------------\n',
#  'Покупать автомобиль у нас УДОБНО:\n',
#  '💳 ОНЛАЙН: возможность выбрать и оплатить автомобиль без визита в салон.\n',
#  '💸 КРЕДИТ: по ставке от 9,9%, 10 банков-партнеров.\n',
#  '💰 СТРАХОВАНИЕ: оформляем ОСАГО, КАСКО.\n',
#  '🔄 TRADE-IN: обменяйте свой авто и получите дополнительную СКИДКУ.\n',
#  '🚘 ТЕСТ-ДРАЙВ: прокатитесь на будущем автомобиле.\n',
#  '---------------------------------------------------------\n',
#  '☎️ Звоните нам! \n',
#  '🔍 Мы расскажем всю правду о состоянии автомобиля. Будем рады Вам помочь!\n',
#  'Таможня: True\n',
#  'Количество владельцев: 4\n',
#  'PTS: ORIGINAL\n',
#  'VIN: WDB**************\n',
#  'Vin разрешение: OK\n',
#  'Год: 2006\n',
#  'Рубли: 640000\n',
#  'Евро: 7496\n',
#  'Доллар: 8556\n',
#  'С салона: False\n',
#  'Координаты: 56.119339:47.302921\n',
#  'Регион: Чебоксары\n',
#  'Временная зона: MSK\n',
#  'Пробег: 266000\n',
#  'Тип автомобиля: SEDAN\n',
#  'Количество дверей: 4\n',
#  'Not class auto\n',
#  'Имя автомобиля: Седан\n',
#  'Not trunk volume min\n',
#  'Марка автомобиля: Mercedes-Benz\n',
#  'Модель автомобиля: C-Класс\n',
#  'Информация: 1.8\xa0MT (163\xa0л.с.), седан, задний, бензин\n',
#  '\n',
#  '=================================================================================================================================\n',
#  'Лицензия: ******|164\n',
#  'Доступность: IN_STOCK\n',
#  'Категория: cars\n',
#  'Цвет: #FAFBFB\n',
#  'Описание: Идеальный вариант для молодого парня или девушки Mercedes A класса. \n',
#  'Автомобиль находится в идеальном состоянии! В дтп не участвовал. \n',
#  'Отличная комплектация: кожаный салон, помощь при парковке, парктроники в круг, AMG пакет, 18 диски, машина вся проклеена в шумоизаляцию, а музыка burmester играет просто шикарно!\n',
#  'ТО с заменой масла делали 2500 км назад. \n',
#  'Пробег 100% родной, любые проверки за ваш счёт! В салоне ещё пахнет новым автомобилем. Лучше смотреть в живую! \n',
#  'Полный комплект документов и ключей!\n',
#  'Таможня: True\n',
#  'Количество владельцев: 2\n',
#  'PTS: ORIGINAL\n',
#  'VIN: WDD**************\n',
#  'Vin разрешение: OK\n',
#  'Год: 2018\n',
#  'Рубли: 2210000\n',
#  'Евро: 25884\n',
#  'Доллар: 29545\n',
#  'С салона: False\n',
#  'Координаты: 55.796288:49.108795\n',
#  'Регион: Казань\n',
#  'Временная зона: MSK\n',
#  'Пробег: 52000\n',
#  'Тип автомобиля: HATCHBACK_5_DOORS\n',
#  'Количество дверей: 5\n',
#  'Класс автомобиля: C\n',
#  'Имя автомобиля: Хэтчбек 5 дв.\n',
#  'Объем багажника: 370\n',
#  'Марка автомобиля: Mercedes-Benz\n',
#  'Модель автомобиля: A-Класс\n',
#  'Информация: 1.3\xa0AMT (150\xa0л.с.), хэтчбек 5 дв., передний, бензин\n',
#  '\n',
#  '=================================================================================================================================\n',
#  'Not license plate \n',
#  'Доступность: IN_STOCK\n',
#  'Категория: cars\n',
#  'Цвет: #0000CC\n',
#  'Описание: Продажа от официального дилера Volvo Car Горки г. Казань. Автомобиль куплен у официального дилера в 2020 г. Автомобиль в отличном техническом состоянии.\n',
#  '\n',
#  'Готовы ответить на все Ваши вопросы каждый день с 8 до 20. \n',
#  'ПРЕИМУЩЕСТВА:\n',
#  ' • Автомобиль прошел полную техническую диагностику \n',
#  '• Гарантия юридической чистоты \n',
#  '• У нас есть Кредитные программы \n',
#  '• Возможность приобрести автомобиль в кредит БЕЗ ПЕРВОНАЧАЛЬНОГО ВЗНОСА \n',
#  '• Все виды страхования (КАСКО, ОСАГО и прочее) \n',
#  '• Услуга Автопобор за наш счет\n',
#  'Примем в зачет Ваш автомобиль на автомобиль с пробегом (обмен с доплатой в обе стороны) Специальное предложение при условии обмена (TRADE-IN) : \n',
#  '* Единовременная скидка до 100 000 рублей на автомобиль с пробегом Место осмотра: \n',
#  'Осмотреть автомобиль можно по адресу: Казань, ул. Родины, д. 1в\n',
#  '\n',
#  'Таможня: True\n',
#  'Количество владельцев: 1\n',
#  'PTS: ORIGINAL\n',
#  'VIN: W1N**************\n',
#  'Vin разрешение: UNKNOWN\n',
#  'Год: 2020\n',
#  'Рубли: 3990000\n',
#  'Евро: 46733\n',
#  'Доллар: 53341\n',
#  'С салона: True\n',
#  'Координаты: 55.761299:49.193642\n',
#  'Регион: Казань\n',
#  'Временная зона: MSK\n',
#  'Пробег: 10000\n',
#  'Тип автомобиля: ALLROAD_5_DOORS\n',
#  'Количество дверей: 5\n',
#  'Класс автомобиля: J\n',
#  'Имя автомобиля: Внедорожник 5 дв.\n',
#  'Объем багажника: 570\n',
#  'Марка автомобиля: Mercedes-Benz\n',
#  'Модель автомобиля: GLB\n',
#  'Информация: 2.0\xa0AMT (224\xa0л.с.), внедорожник, полный, бензин\n',
#  '\n',
#  '=================================================================================================================================\n',
#  'Not license plate \n',
#  'Доступность: IN_STOCK\n',
#  'Категория: cars\n',
#  'Цвет: #0000CC\n',
#  'Описание: ✅Продажа от собственника!\n',
#  '\n',
#  '✅Автомобиль в идеальном состоянии\n',
#  '\n',
#  '✅Без ДТП, полностью в родном окрасе\n',
#  '\n',
#  '✅Вся история у официального дилера\n',
#  '\n',
#  'ТО каждые 7000 км, оригинальные запчасти, масло заливалось только AMG\n',
#  '\n',
#  'Дополнительно:\n',
#  '-2 Слоя керамики\n',
#  '-Гидрофобное покрытие на весь кузов и стекла\n',
#  '-Керамическая пропитка кожи в салоне\n',
#  '-Оклеен капот в полиуретановую защитную пленку\n',
#  '-Атермальная тонировка на все стекла по ГОСТу\n',
#  '-Затемнённый хром\n',
#  '-Эксклюзивные воздуховоды с подсветкой от рестайлинга\n',
#  '-Спойлер AMG\n',
#  '-Зима на оригинальных дисках Mercedes, резина Michelin X-Ice North 4\n',
#  '-Лето R20 оригинал AMG\n',
#  '\n',
#  'Комплектация: \n',
#  'Цвет Синий кавансит металик (890)\n',
#  'Цвет салона черный (кожа Nappa Эксклюзив AMG)\n',
#  '223 Заднее сиденье с электрорегулировками и функцией запоминания параметров 233 DISTRONIC PLUS\n',
#  '235 Активный парковочный ассистент включая PARKTRONIC\n',
#  '237 Активная система контроля "мертвых" зон\n',
#  '238 Активная система удержания полосы движения\n',
#  '249 Внутреннее и боковое зеркало заднего вида со стороны водителя с автоматическим затемнением\n',
#  '253 Система превентивной защиты и предупреждения при вероятности столкновения сзади Pre-Safe\n',
#  '266 DISTRONIC PLUS с ассистентом рулевого управления и система помощи при движении в пробках Stop & Go Pilot\n',
#  '268 Система BAS Plus с функцией помощи при движении на перекрестках\n',
#  '269 Система BAS PLUS с расширенными функциями\n',
#  '271 Система торможения с функцией защиты пешеходов PRE-SAFE PLUS\n',
#  '275 Запоминание настроек рулевой колонки и внешних боковых зеркал\n',
#  '276 Система запоминания параметров для задних сидений\n',
#  '297 Солнцезащитные шторки в задних дверях, с электроприводом\n',
#  '300 Система торможения для смягчения столкновения PRE-SAFE\n',
#  '314 Спортивный трехспицевый руль с отделкой кожей и деревом\n',
#  '401 Сиденья повышенной комфортности спереди\n',
#  '402 Сиденья повышенной комфортности сзади\n',
#  '406 Мультиконтурные задние сиденья с функцией массажа ENERGIZING\n',
#  '413 Панорамная стеклянная сдвижная крыша с электроприводом\n',
#  '427 AMG Speedshift MCT 7G\n',
#  '432 Пакет "Комфортные сидения спереди" включая динамические мультиконтурные передние сиденья с функцией массажа ENERGIZING\n',
#  '439 Комфортные подголовники EASY ADJUST для водителя и переднего пассажира 443 Руль с подогревом\n',
#  '452 Смещаемое на 77 мм вперед сиденье переднего пассажира\n',
#  '453 Положение сидений "Executive" на стороне переднего пассажира\n',
#  '463 Head-up-Display\n',
#  '475 Система контроля давления в шинах 481 Защита картера двигателя\n',
#  '501 Камера 360°\n',
#  '513 Система Traffic Sign Assist\n',
#  '531 COMAND Online\n',
#  '540 Солнцезащитная электрическая шторка на заднем стекле 551 Противоугонная система с защитой от проникновения в салон\n',
#  '582 THERMOTRONIC в задней части салона\n',
#  '596 Теплозащитное круговое остекление, отражающее инфракрасное излучение\n',
#  '597 Обогрев лобового стекла\n',
#  '61U Отделка потолка Dinamica черного цвета\n',
#  '628 Адаптивный ассистент дальнего света\n',
#  '642 Фары LED Intelligent Light System\n',
#  '735 Расширенная отделка деревом\n',
#  '753 Кованые диски AMG 20", дизайн 5 сдвоенных спиц, цвет серый титан, вкл. крышку на колесные болты черного цвета\n',
#  '772 Стайлинг AMG\n',
#  '776 Расширенные колесные арки AMG\n',
#  '806 Модельный год\n',
#  '811 Акустическая система Burmester High-End 3D-Surround-Soundsystem\n',
#  '840 Боковые стекла сзади и заднее стекло с тонировкой\n',
#  '864 Мультимедийная система для пассажиров сзади\n',
#  '871 Функция Hands-Free-Access\n',
#  '874 MAGIC VISION CONTROL, с обогревом\n',
#  '877 Ambient Lighting\n',
#  '881 Дистанционное запирание крышки багажника вкл.сервозакрывание\n',
#  '882 Сигнализация проникновения в салон\n',
#  '883 Сервозакрывание дверей и крышки багажника\n',
#  '887 Отдельно механически запираемая крышка багажника\n',
#  '889 Система KEYLESS-GO\n',
#  '902 Подогрев передних сидений Plus\n',
#  '903 Подогрев боковых задних сидений Plus\n',
#  '906 Подогрев подлокотников в передней части салона\n',
#  '907 Подогрев подлокотников в задней части салона\n',
#  '915 Топливный бак на 80 л.\n',
#  'B03 Функция ECO start/stop\n',
#  'B09 Refrigerant compressor with magnetic clutch\n',
#  'K11 Адаптивные тормозные фонари\n',
#  'K15 Межсервисный пробег 15 000 км\n',
#  'LS2 Технический код\n',
#  'P07 Пакет "Личный водитель"\n',
#  'P09 Солнцезащитный пакет\n',
#  'P17 Пакет KEYLESS-GO\n',
#  'P20 Пакет активных систем помощи водителю Plus\n',
#  'P21 Пакет AIR-BALANCE\n',
#  'P34 Пакет Эксклюзив\n',
#  'P35 LED Intelligent Light System\n',
#  'P43 Пакет Комфортные сидения сзади\n',
#  'P44 Пакет систем помощи при парковке\n',
#  'P46 Индивидуальная система развлечений в задней части салона\n',
#  'P54 Противоугонный пакет\n',
#  'P64 Система запоминания параметров (для водителя и переднего пассажира)\n',
#  'P69 Пакет "Комфорт"\n',
#  '03B Инструкция по эксплуатации и сервисная книжка на русском языке\n',
#  'U01 Индикация непристегнутых ремней безопасности в задней части салона\n',
#  'U10 Автоматическое отключение подушки безопасности переднего пассажира\n',
#  'U25 Пороги с подсветкой\n',
#  'U26 Коврики AMG\n',
#  'U67 Розетка 230V в задней части салона (отсутствие розетки 12V сзади)\n',
#  'H10 Элементы декоративной отделки AMG Карбон/Черный рояльный лак\n',
#  '815 DVD-плейер\n',
#  'U70 Тормозные скобы, окрашенные в красный цвет с надписью AMG\n',
#  'B51 Ремкомплект Tirefit\n',
#  'P60 Пакет AMG Night\n',
#  'Таможня: True\n',
#  'Количество владельцев: 2\n',
#  'PTS: ORIGINAL\n',
#  'VIN: WDD**************\n',
#  'Vin разрешение: OK\n',
#  'Год: 2016\n',
#  'Рубли: 6440000\n',
#  'Евро: 75429\n',
#  'Доллар: 86094\n',
#  'С салона: False\n',
#  'Координаты: 55.81741:49.128017\n',
#  'Регион: Казань\n',
#  'Временная зона: MSK\n',
#  'Пробег: 52000\n',
#  'Тип автомобиля: SEDAN\n',
#  'Количество дверей: 4\n',
#  'Класс автомобиля: F\n',
#  'Имя автомобиля: Седан Long\n',
#  'Объем багажника: 510\n',
#  'Марка автомобиля: Mercedes-Benz\n',
#  'Модель автомобиля: S-Класс AMG\n',
#  'Информация: 5.5\xa0AT (585\xa0л.с.), седан, полный, бензин\n',
#  '\n',
#  '=================================================================================================================================\n',
#  'Not license plate \n',
#  'Доступность: IN_STOCK\n',
#  'Категория: cars\n',
#  'Цвет: #040001\n',
#  'Описание: «МБ-Орловка» — официальный дилер Mercedes-Benz в Набережных Челнах. Мы рады пригласить Вас в наш Дилерский центр.\n',
#  'МБ-Орловка предлагает полный комплекс услуг:\n',
#  '• Продажа новых легковых и малотоннажных автомобилей Mercedes-Benz;\n',
#  '• Trade-in и продажа автомобилей с пробегом, включая автомобили Mercedes-Benz Certified;\n',
#  '• Полный спектр финансовых услуг: кредитование, страхование, лизинг;\n',
#  '• Продажа оригинальных запасных частей и аксессуаров Mercedes-Benz;\n',
#  '• Гарантийное и постгарантийное обслуживание автомобилей Mercedes-Benz;\n',
#  '• Кузовной ремонт автомобилей Mercedes-Benz любой сложности.\n',
#  '\n',
#  'Все автомобили с пробегом проходят полную диагностику официального дилера и проверку юридической чистоты. Мы рады предложить вам проверенные автомобили с пробегом, на условиях полной оплаты, обмена на Ваш автомобиль и с использованием финансовых услуг: кредит, страховка, лизинг.\n',
#  'Если Вас заинтересовал наш автомобиль, обращайтесь, наши специалисты ответят на все интересующие Вас вопросы.\n',
#  '\n',
#  'Комплектация: AMG GT 53 4MATIC+ \n',
#  'Цвет кузова: черный обсидиан\n',
#  ...]

# %% [markdown]
# Выделим признаки, которые будем исследовать:

# %%
signs = ['Рубли', 'Пробег', 'Количество дверей', 'Объем багажника', 
         'Количество владельцев', 'Год', 'Лицензия', 'С салона', 'Цвет', 
         'Временная зона', 'Марка автомобиля', 'Модель автомобиля', 'Тип автомобиля']

# %% [markdown]
# Для каждого автомобиля выделим имеющиеся признаки:

# %%
separator = '=================================================================================================================================\n'
index = 0
labels = [[]]
for i in range(len(newlines)):
    if newlines[i]:
        first_word = newlines[i].split(':')[0]
        if first_word in signs:
            second_word = newlines[i].split(': ')[1].replace("\n","")
            labels[index].append((first_word, second_word))
        if newlines[i] == separator:
            index += 1
            labels.append([])
labels.pop()

# Uncomment to see the collected objects:
labels
# Out:
# [[('Лицензия', '******|18'),
#   ('Цвет', '#040001'),
#   ('Количество владельцев', '4'),
#   ('Год', '2010'),
#   ('Рубли', '1360000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '174000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'S-Класс')],
#  [('Лицензия', '******|716'),
#   ('Цвет', '#97948F'),
#   ('Количество владельцев', '1'),
#   ('Год', '2019'),
#   ('Рубли', '4310000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '28000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'A-Класс AMG')],
#  [('Лицензия', '******|716'),
#   ('Цвет', '#FAFBFB'),
#   ('Количество владельцев', '1'),
#   ('Год', '2020'),
#   ('Рубли', '7120000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '15000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLE')],
#  [('Лицензия', '******|156'),
#   ('Цвет', '#040001'),
#   ('Количество владельцев', '4'),
#   ('Год', '2011'),
#   ('Рубли', '1520000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '137000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'E-Класс')],
#  [('Цвет', '#040001'),
#   ('Количество владельцев', '4'),
#   ('Год', '2003'),
#   ('Рубли', '380000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '375000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'C-Класс')],
#  [('Цвет', '#040001'),
#   ('Количество владельцев', '4'),
#   ('Год', '2010'),
#   ('Рубли', '1220000'),
#   ('С салона', 'True'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '199000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'S-Класс')],
#  [('Лицензия', '******|199'),
#   ('Цвет', '#97948F'),
#   ('Количество владельцев', '3'),
#   ('Год', '2005'),
#   ('Рубли', '880000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '195000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'S-Класс')],
#  [('Цвет', '#040001'),
#   ('Количество владельцев', '2'),
#   ('Год', '2020'),
#   ('Рубли', '11690000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '8000'),
#   ('Тип автомобиля', 'LIFTBACK'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'AMG GT')],
#  [('Цвет', '#0000CC'),
#   ('Количество владельцев', '1'),
#   ('Год', '2019'),
#   ('Рубли', '4210000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '27000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'E-Класс')],
#  [('Цвет', '#0000CC'),
#   ('Количество владельцев', '3'),
#   ('Год', '2017'),
#   ('Рубли', '4620000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '67000'),
#   ('Тип автомобиля', 'COUPE'),
#   ('Количество дверей', '2'),
#   ('Объем багажника', '425'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'E-Класс')],
#  [('Цвет', '#FAFBFB'),
#   ('Количество владельцев', '2'),
#   ('Год', '2013'),
#   ('Рубли', '3030000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '126000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'M-Класс')],
#  [('Цвет', '#CACECB'),
#   ('Количество владельцев', '4'),
#   ('Год', '2001'),
#   ('Рубли', '490000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '318000'),
#   ('Тип автомобиля', 'HATCHBACK_3_DOORS'),
#   ('Количество дверей', '3'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'C-Класс')],
#  [('Лицензия', '******|163'),
#   ('Цвет', '#FAFBFB'),
#   ('Количество владельцев', '3'),
#   ('Год', '2015'),
#   ('Рубли', '4790000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '120000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Объем багажника', '650'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLE Coupe AMG')],
#  [('Лицензия', '******|77'),
#   ('Цвет', '#040001'),
#   ('Количество владельцев', '1'),
#   ('Год', '2021'),
#   ('Рубли', '9360000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '5000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Объем багажника', '655'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLE Coupe')],
#  [('Лицензия', '******|21'),
#   ('Цвет', '#040001'),
#   ('Количество владельцев', '4'),
#   ('Год', '2013'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '235000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'E-Класс')],
#  [('Цвет', '#CACECB'),
#   ('Количество владельцев', '2'),
#   ('Год', '2013'),
#   ('Рубли', '2210000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '102000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLK-Класс')],
#  [('Лицензия', '******|763'),
#   ('Цвет', '#97948F'),
#   ('Количество владельцев', '2'),
#   ('Год', '2018'),
#   ('Рубли', '6100000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '101000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'CLS')],
#  [('Цвет', '#040001'),
#   ('Количество владельцев', '4'),
#   ('Год', '2006'),
#   ('Рубли', '640000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '266000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'C-Класс')],
#  [('Лицензия', '******|164'),
#   ('Цвет', '#FAFBFB'),
#   ('Количество владельцев', '2'),
#   ('Год', '2018'),
#   ('Рубли', '2210000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '52000'),
#   ('Тип автомобиля', 'HATCHBACK_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Объем багажника', '370'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'A-Класс')],
#  [('Цвет', '#0000CC'),
#   ('Количество владельцев', '1'),
#   ('Год', '2020'),
#   ('Рубли', '3990000'),
#   ('С салона', 'True'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '10000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Объем багажника', '570'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLB')],
#  [('Цвет', '#0000CC'),
#   ('Количество владельцев', '2'),
#   ('Год', '2016'),
#   ('Рубли', '6440000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '52000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Объем багажника', '510'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'S-Класс AMG')],
#  [('Цвет', '#040001'),
#   ('Год', '2021'),
#   ('Рубли', '13070000'),
#   ('С салона', 'True'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '0'),
#   ('Тип автомобиля', 'LIFTBACK'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'AMG GT')],
#  [('Цвет', '#040001'),
#   ('Количество владельцев', '3'),
#   ('Год', '2012'),
#   ('Рубли', '1350000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '150000'),
#   ('Тип автомобиля', 'COUPE_HARDTOP'),
#   ('Количество дверей', '2'),
#   ('Объем багажника', '450'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'E-Класс')],
#  [('Цвет', '#200204'),
#   ('Количество владельцев', '4'),
#   ('Год', '2013'),
#   ('Рубли', '1160000'),
#   ('С салона', 'True'),
#   ('Временная зона', '+04'),
#   ('Пробег', '89000'),
#   ('Тип автомобиля', 'HATCHBACK_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'B-Класс')],
#  [('Лицензия', '******|763'),
#   ('Цвет', '#97948F'),
#   ('Количество владельцев', '2'),
#   ('Год', '2016'),
#   ('Рубли', '2870000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '35000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Объем багажника', '421'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLA')],
#  [('Цвет', '#FAFBFB'),
#   ('Количество владельцев', '4'),
#   ('Год', '2015'),
#   ('Рубли', '3470000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '164000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GL-Класс')],
#  [('Цвет', '#97948F'),
#   ('Количество владельцев', '4'),
#   ('Год', '2009'),
#   ('Рубли', '870000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '197000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'C-Класс')],
#  [('Цвет', '#040001'),
#   ('Количество владельцев', '1'),
#   ('Год', '2020'),
#   ('Рубли', '8980000'),
#   ('С салона', 'True'),
#   ('Временная зона', '+04'),
#   ('Пробег', '11000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLE')],
#  [('Цвет', '#FAFBFB'),
#   ('Количество владельцев', '1'),
#   ('Год', '2021'),
#   ('Рубли', '5290000'),
#   ('С салона', 'True'),
#   ('Временная зона', '+04'),
#   ('Пробег', '5000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLC')],
#  [('Цвет', '#FAFBFB'),
#   ('Количество владельцев', '4'),
#   ('Год', '2018'),
#   ('Рубли', '2490000'),
#   ('С салона', 'True'),
#   ('Временная зона', '+04'),
#   ('Пробег', '43000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'C-Класс')],
#  [('Цвет', '#040001'),
#   ('Количество владельцев', '1'),
#   ('Год', '2021'),
#   ('Рубли', '16520000'),
#   ('С салона', 'True'),
#   ('Временная зона', '+04'),
#   ('Пробег', '2000'),
#   ('Тип автомобиля', 'LIFTBACK'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'AMG GT')],
#  [('Цвет', '#0000CC'),
#   ('Количество владельцев', '2'),
#   ('Год', '2017'),
#   ('Рубли', '4780000'),
#   ('С салона', 'True'),
#   ('Временная зона', '+04'),
#   ('Пробег', '112000'),
#   ('Тип автомобиля', 'MINIVAN'),
#   ('Количество дверей', '5'),
#   ('Объем багажника', '1030'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'V-Класс')],
#  [('Цвет', '#FAFBFB'),
#   ('Количество владельцев', '2'),
#   ('Год', '2017'),
#   ('Рубли', '5310000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '160000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Объем багажника', '650'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLE Coupe')],
#  [('Цвет', '#97948F'),
#   ('Год', '2021'),
#   ('Рубли', '5420000'),
#   ('С салона', 'True'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '0'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLC')],
#  [('Цвет', '#0000CC'),
#   ('Количество владельцев', '2'),
#   ('Год', '2012'),
#   ('Рубли', '2110000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '68000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'E-Класс')],
#  [('Цвет', '#040001'),
#   ('Количество владельцев', '2'),
#   ('Год', '2019'),
#   ('Рубли', '8620000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '19000'),
#   ('Тип автомобиля', 'PICKUP_TWO'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'X-Класс')],
#  [('Цвет', '#97948F'),
#   ('Количество владельцев', '1'),
#   ('Год', '2017'),
#   ('Рубли', '7830000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '68000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Объем багажника', '510'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'S-Класс')],
#  [('Лицензия', '******|116'),
#   ('Цвет', '#040001'),
#   ('Количество владельцев', '4'),
#   ('Год', '2007'),
#   ('Рубли', '910000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '235000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'S-Класс')],
#  [('Лицензия', '******|119'),
#   ('Цвет', '#FAFBFB'),
#   ('Количество владельцев', '4'),
#   ('Год', '2012'),
#   ('Рубли', '1240000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '208000'),
#   ('Тип автомобиля', 'COUPE_HARDTOP'),
#   ('Количество дверей', '2'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'E-Класс')],
#  [('Лицензия', '******|18'),
#   ('Цвет', '#97948F'),
#   ('Количество владельцев', '2'),
#   ('Год', '2019'),
#   ('Рубли', '6550000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '8000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'CLA AMG')],
#  [('Цвет', '#0000CC'),
#   ('Количество владельцев', '3'),
#   ('Год', '2018'),
#   ('Рубли', '5880000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '60000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLE Coupe')],
#  [('Цвет', '#CACECB'),
#   ('Количество владельцев', '2'),
#   ('Год', '2012'),
#   ('Рубли', '2660000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '108000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'M-Класс')],
#  [('Лицензия', '******|43'),
#   ('Цвет', '#FAFBFB'),
#   ('Количество владельцев', '2'),
#   ('Год', '2019'),
#   ('Рубли', '8400000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '36000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLS')],
#  [('Лицензия', '******|73'),
#   ('Цвет', '#040001'),
#   ('Количество владельцев', '4'),
#   ('Год', '2008'),
#   ('Рубли', '1460000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '211000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'M-Класс')],
#  [('Лицензия', '******|716'),
#   ('Цвет', '#040001'),
#   ('Количество владельцев', '2'),
#   ('Год', '2017'),
#   ('Рубли', '2650000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '36000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLA')],
#  [('Лицензия', '******|716'),
#   ('Цвет', '#040001'),
#   ('Количество владельцев', '1'),
#   ('Год', '2017'),
#   ('Рубли', '4510000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '61000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'E-Класс')],
#  [('Цвет', '#FAFBFB'),
#   ('Количество владельцев', '1'),
#   ('Год', '2021'),
#   ('Рубли', '11750000'),
#   ('С салона', 'True'),
#   ('Временная зона', '+04'),
#   ('Пробег', '1000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLE Coupe')],
#  [('Цвет', '#040001'),
#   ('Количество владельцев', '2'),
#   ('Год', '2015'),
#   ('Рубли', '2030000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '49000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'E-Класс')],
#  [('Цвет', '#97948F'),
#   ('Количество владельцев', '1'),
#   ('Год', '2016'),
#   ('Рубли', '3120000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '111000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLC')],
#  [('Цвет', '#040001'),
#   ('Количество владельцев', '4'),
#   ('Год', '2007'),
#   ('Рубли', '490000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '151000'),
#   ('Тип автомобиля', 'HATCHBACK_3_DOORS'),
#   ('Количество дверей', '3'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'A-Класс')],
#  [('Цвет', '#040001'),
#   ('Количество владельцев', '1'),
#   ('Год', '2018'),
#   ('Рубли', '4100000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '64000'),
#   ('Тип автомобиля', 'COUPE'),
#   ('Количество дверей', '2'),
#   ('Объем багажника', '425'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'E-Класс')],
#  [('Цвет', '#97948F'),
#   ('Количество владельцев', '1'),
#   ('Год', '2016'),
#   ('Рубли', '5560000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '68000'),
#   ('Тип автомобиля', 'COUPE'),
#   ('Количество дверей', '2'),
#   ('Объем багажника', '400'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'S-Класс')],
#  [('Цвет', '#040001'),
#   ('Количество владельцев', '2'),
#   ('Год', '2019'),
#   ('Рубли', '4250000'),
#   ('С салона', 'True'),
#   ('Временная зона', '+04'),
#   ('Пробег', '21000'),
#   ('Тип автомобиля', 'COUPE'),
#   ('Количество дверей', '2'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'C-Класс')],
#  [('Цвет', '#040001'),
#   ('Количество владельцев', '1'),
#   ('Год', '2021'),
#   ('Рубли', '7780000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '1000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Объем багажника', '630'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLE')],
#  [('Лицензия', '******|763'),
#   ('Цвет', '#FAFBFB'),
#   ('Количество владельцев', '1'),
#   ('Год', '2021'),
#   ('Рубли', '6000000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '13000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'E-Класс')],
#  [('Лицензия', '******|18'),
#   ('Цвет', '#FAFBFB'),
#   ('Количество владельцев', '2'),
#   ('Год', '2017'),
#   ('Рубли', '3360000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '111000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'E-Класс')],
#  [('Цвет', '#040001'),
#   ('Количество владельцев', '1'),
#   ('Год', '2021'),
#   ('Рубли', '4680000'),
#   ('С салона', 'True'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '18000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLB')],
#  [('Цвет', '#FAFBFB'),
#   ('Количество владельцев', '4'),
#   ('Год', '2014'),
#   ('Рубли', '1260000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '164000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'E-Класс')],
#  [('Лицензия', '******|18'),
#   ('Цвет', '#040001'),
#   ('Количество владельцев', '4'),
#   ('Год', '2002'),
#   ('Рубли', '360000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '185000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'S-Класс')],
#  [('Лицензия', '******|43'),
#   ('Цвет', '#97948F'),
#   ('Количество владельцев', '4'),
#   ('Год', '2018'),
#   ('Рубли', '4810000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '137000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Объем багажника', '540'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'E-Класс AMG')],
#  [('Цвет', '#040001'),
#   ('Год', '2021'),
#   ('Рубли', '6530000'),
#   ('С салона', 'True'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '0'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Объем багажника', '550'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLC')],
#  [('Лицензия', '******|163'),
#   ('Цвет', '#97948F'),
#   ('Количество владельцев', '3'),
#   ('Год', '2020'),
#   ('Рубли', '3730000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '39000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'E-Класс')],
#  [('Цвет', '#FAFBFB'),
#   ('Количество владельцев', '1'),
#   ('Год', '2018'),
#   ('Рубли', '3800000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '81000'),
#   ('Тип автомобиля', 'COUPE'),
#   ('Количество дверей', '2'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'C-Класс')],
#  [('Цвет', '#97948F'),
#   ('Год', '2021'),
#   ('Рубли', '5270000'),
#   ('С салона', 'True'),
#   ('Временная зона', '+04'),
#   ('Пробег', '0'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Объем багажника', '550'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLC')],
#  [('Цвет', '#040001'),
#   ('Год', '2021'),
#   ('Рубли', '24460000'),
#   ('С салона', 'True'),
#   ('Временная зона', '+04'),
#   ('Пробег', '0'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'Maybach GLS')],
#  [('Цвет', '#040001'),
#   ('Год', '2020'),
#   ('Рубли', '17510000'),
#   ('С салона', 'True'),
#   ('Временная зона', '+04'),
#   ('Пробег', '0'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'S-Класс')],
#  [('Цвет', '#0000CC'),
#   ('Год', '2021'),
#   ('Рубли', '13210000'),
#   ('С салона', 'True'),
#   ('Временная зона', '+04'),
#   ('Пробег', '0'),
#   ('Тип автомобиля', 'LIFTBACK'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'AMG GT')],
#  [('Цвет', '#040001'),
#   ('Количество владельцев', '4'),
#   ('Год', '2007'),
#   ('Рубли', '840000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '162000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'C-Класс')],
#  [('Лицензия', '******|716'),
#   ('Цвет', '#97948F'),
#   ('Количество владельцев', '4'),
#   ('Год', '2010'),
#   ('Рубли', '950000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '158000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'E-Класс')],
#  [('Лицензия', '******|716'),
#   ('Цвет', '#040001'),
#   ('Количество владельцев', '2'),
#   ('Год', '2018'),
#   ('Рубли', '8840000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '46000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'S-Класс AMG')],
#  [('Лицензия', '******|716'),
#   ('Цвет', '#040001'),
#   ('Количество владельцев', '1'),
#   ('Год', '2019'),
#   ('Рубли', '17820000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '76000'),
#   ('Тип автомобиля', 'MINIVAN'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'V-Класс')],
#  [('Лицензия', '******|18'),
#   ('Цвет', '#FAFBFB'),
#   ('Количество владельцев', '4'),
#   ('Год', '2015'),
#   ('Рубли', '2190000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '72000'),
#   ('Тип автомобиля', 'WAGON_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'CLA')],
#  [('Лицензия', '******|716'),
#   ('Цвет', '#97948F'),
#   ('Количество владельцев', '3'),
#   ('Год', '2013'),
#   ('Рубли', '1610000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '227000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Объем багажника', '450'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLK-Класс')],
#  [('Лицензия', '******|763'),
#   ('Цвет', '#040001'),
#   ('Количество владельцев', '2'),
#   ('Год', '2019'),
#   ('Рубли', '4090000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '56000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLC Coupe')],
#  [('Цвет', '#040001'),
#   ('Год', '2021'),
#   ('Рубли', '12790000'),
#   ('С салона', 'True'),
#   ('Временная зона', '+04'),
#   ('Пробег', '0'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLS')],
#  [('Цвет', '#97948F'),
#   ('Год', '2021'),
#   ('Рубли', '6410000'),
#   ('С салона', 'True'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '0'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLC Coupe')],
#  [('Цвет', '#040001'),
#   ('Год', '2021'),
#   ('Рубли', '21660000'),
#   ('С салона', 'True'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '0'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'Maybach GLS')],
#  [('Цвет', '#040001'),
#   ('Год', '2021'),
#   ('Рубли', '13770000'),
#   ('С салона', 'True'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '0'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'S-Класс')],
#  [('Цвет', '#040001'),
#   ('Год', '2021'),
#   ('Рубли', '13820000'),
#   ('С салона', 'True'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '0'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'S-Класс')],
#  [('Цвет', '#0000CC'),
#   ('Год', '2021'),
#   ('Рубли', '5800000'),
#   ('С салона', 'True'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '0'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLC Coupe')],
#  [('Цвет', '#040001'),
#   ('Количество владельцев', '2'),
#   ('Год', '2014'),
#   ('Рубли', '4400000'),
#   ('С салона', 'True'),
#   ('Временная зона', '+04'),
#   ('Пробег', '87000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'S-Класс AMG')],
#  [('Цвет', '#FAFBFB'),
#   ('Количество владельцев', '2'),
#   ('Год', '2017'),
#   ('Рубли', '5020000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '154000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLE Coupe')],
#  [('Цвет', '#040001'),
#   ('Год', '2021'),
#   ('Рубли', '16650000'),
#   ('С салона', 'True'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '0'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'S-Класс')],
#  [('Цвет', '#97948F'),
#   ('Год', '2021'),
#   ('Рубли', '10860000'),
#   ('С салона', 'True'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '0'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLS')],
#  [('Цвет', '#040001'),
#   ('Год', '2021'),
#   ('Рубли', '5170000'),
#   ('С салона', 'True'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '0'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Объем багажника', '540'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'E-Класс')],
#  [('Лицензия', '******|716'),
#   ('Цвет', '#040001'),
#   ('Количество владельцев', '3'),
#   ('Год', '2010'),
#   ('Рубли', '1250000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '153000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Объем багажника', '551'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'M-Класс')],
#  [('Лицензия', '******|152'),
#   ('Цвет', '#040001'),
#   ('Количество владельцев', '1'),
#   ('Год', '1996'),
#   ('Рубли', '330000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '289000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'E-Класс')],
#  [('Цвет', '#040001'),
#   ('Количество владельцев', '1'),
#   ('Год', '2020'),
#   ('Рубли', '9740000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '48000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLS')],
#  [('Цвет', '#FAFBFB'),
#   ('Год', '2021'),
#   ('Рубли', '5290000'),
#   ('С салона', 'True'),
#   ('Временная зона', '+04'),
#   ('Пробег', '0'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Объем багажника', '570'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLB')],
#  [('Лицензия', '******|163'),
#   ('Цвет', '#040001'),
#   ('Количество владельцев', '3'),
#   ('Год', '2017'),
#   ('Рубли', '4100000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '54000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLC Coupe AMG')],
#  [('Цвет', '#0000CC'),
#   ('Год', '2021'),
#   ('Рубли', '5310000'),
#   ('С салона', 'True'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '0'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLC')],
#  [('Цвет', '#040001'),
#   ('Количество владельцев', '2'),
#   ('Год', '2020'),
#   ('Рубли', '4570000'),
#   ('С салона', 'True'),
#   ('Временная зона', '+04'),
#   ('Пробег', '21000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLC')],
#  [('Цвет', '#040001'),
#   ('Количество владельцев', '2'),
#   ('Год', '2015'),
#   ('Рубли', '2710000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '277000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'S-Класс')],
#  [('Цвет', '#040001'),
#   ('Год', '2021'),
#   ('Рубли', '15970000'),
#   ('С салона', 'True'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '0'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'S-Класс')],
#  [('Лицензия', '******|73'),
#   ('Цвет', '#CACECB'),
#   ('Количество владельцев', '3'),
#   ('Год', '2005'),
#   ('Рубли', '610000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '223000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'M-Класс')],
#  [('Цвет', '#EE1D19'),
#   ('Количество владельцев', '1'),
#   ('Год', '2018'),
#   ('Рубли', '2620000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '35000'),
#   ('Тип автомобиля', 'HATCHBACK_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Объем багажника', '370'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'A-Класс')],
#  [('Цвет', '#0000CC'),
#   ('Год', '2021'),
#   ('Рубли', '4870000'),
#   ('С салона', 'True'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '0'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLC')],
#  [('Цвет', '#040001'),
#   ('Количество владельцев', '4'),
#   ('Год', '2011'),
#   ('Рубли', '1340000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '170000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Объем багажника', '560'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'S-Класс')],
#  [('Цвет', '#040001'),
#   ('Год', '2021'),
#   ('Рубли', '21640000'),
#   ('С салона', 'True'),
#   ('Временная зона', '+04'),
#   ('Пробег', '0'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'Maybach GLS')],
#  [('Цвет', '#FAFBFB'),
#   ('Год', '2021'),
#   ('Рубли', '10890000'),
#   ('С салона', 'True'),
#   ('Временная зона', '+04'),
#   ('Пробег', '0'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLS')],
#  [('Цвет', '#040001'),
#   ('Количество владельцев', '1'),
#   ('Год', '2021'),
#   ('Рубли', '8510000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '1000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Объем багажника', '630'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLE')],
#  [('Лицензия', '******|163'),
#   ('Цвет', '#FAFBFB'),
#   ('Количество владельцев', '4'),
#   ('Год', '2010'),
#   ('Рубли', '1490000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '51000'),
#   ('Тип автомобиля', 'COUPE_HARDTOP'),
#   ('Количество дверей', '2'),
#   ('Объем багажника', '450'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'E-Класс')],
#  [('Цвет', '#040001'),
#   ('Количество владельцев', '2'),
#   ('Год', '2019'),
#   ('Рубли', '3620000'),
#   ('С салона', 'True'),
#   ('Временная зона', '+04'),
#   ('Пробег', '94000'),
#   ('Тип автомобиля', 'MINIVAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'Vito')],
#  [('Цвет', '#CACECB'),
#   ('Количество владельцев', '4'),
#   ('Год', '2003'),
#   ('Рубли', '650000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+05'),
#   ('Пробег', '488000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'E-Класс')],
#  [('Цвет', '#97948F'),
#   ('Количество владельцев', '1'),
#   ('Год', '2018'),
#   ('Рубли', '4920000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '94000'),
#   ('Тип автомобиля', 'MINIVAN'),
#   ('Количество дверей', '5'),
#   ('Объем багажника', '1030'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'V-Класс')],
#  [('Цвет', '#040001'),
#   ('Год', '2021'),
#   ('Рубли', '4820000'),
#   ('С салона', 'True'),
#   ('Временная зона', '+04'),
#   ('Пробег', '0'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Объем багажника', '570'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLB')],
#  [('Цвет', '#040001'),
#   ('Год', '2021'),
#   ('Рубли', '5880000'),
#   ('С салона', 'True'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '0'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Объем багажника', '540'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'E-Класс')],
#  [('Лицензия', '******|56'),
#   ('Цвет', '#040001'),
#   ('Количество владельцев', '4'),
#   ('Год', '1992'),
#   ('Рубли', '150000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '239000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'W124')],
#  [('Цвет', '#040001'),
#   ('Год', '2021'),
#   ('Рубли', '6190000'),
#   ('С салона', 'True'),
#   ('Временная зона', '+04'),
#   ('Пробег', '0'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLC')],
#  [('Цвет', '#22A0F8'),
#   ('Количество владельцев', '3'),
#   ('Год', '2009'),
#   ('Рубли', '1410000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '150000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'E-Класс')],
#  [('Цвет', '#040001'),
#   ('Год', '2021'),
#   ('Рубли', '5350000'),
#   ('С салона', 'True'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '0'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLC')],
#  [('Лицензия', '******|73'),
#   ('Цвет', '#CACECB'),
#   ('Количество владельцев', '2'),
#   ('Год', '2013'),
#   ('Рубли', '1480000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '229000'),
#   ('Тип автомобиля', 'COUPE'),
#   ('Количество дверей', '2'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'C-Класс')],
#  [('Цвет', '#FAFBFB'),
#   ('Количество владельцев', '4'),
#   ('Год', '2014'),
#   ('Рубли', '2350000'),
#   ('С салона', 'True'),
#   ('Временная зона', '+04'),
#   ('Пробег', '227000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'M-Класс')],
#  [('Цвет', '#FAFBFB'),
#   ('Год', '2021'),
#   ('Рубли', '6140000'),
#   ('С салона', 'True'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '0'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLC Coupe')],
#  [('Цвет', '#FAFBFB'),
#   ('Год', '2021'),
#   ('Рубли', '4470000'),
#   ('С салона', 'True'),
#   ('Временная зона', '+04'),
#   ('Пробег', '0'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLB')],
#  [('Цвет', '#97948F'),
#   ('Количество владельцев', '2'),
#   ('Год', '2019'),
#   ('Рубли', '3790000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '78000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Объем багажника', '540'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'E-Класс')],
#  [('Цвет', '#0000CC'),
#   ('Год', '2022'),
#   ('Рубли', '5430000'),
#   ('С салона', 'True'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '0'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLC')],
#  [('Цвет', '#040001'),
#   ('Количество владельцев', '1'),
#   ('Год', '2015'),
#   ('Рубли', '3050000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '106000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'M-Класс')],
#  [('Цвет', '#040001'),
#   ('Год', '2021'),
#   ('Рубли', '6490000'),
#   ('С салона', 'True'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '0'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLC Coupe')],
#  [('Цвет', '#040001'),
#   ('Количество владельцев', '1'),
#   ('Год', '2020'),
#   ('Рубли', '8810000'),
#   ('С салона', 'True'),
#   ('Временная зона', '+04'),
#   ('Пробег', '17000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLE Coupe')],
#  [('Цвет', '#040001'),
#   ('Количество владельцев', '4'),
#   ('Год', '2010'),
#   ('Рубли', '880000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '139000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'C-Класс')],
#  [('Цвет', '#040001'),
#   ('Год', '2021'),
#   ('Рубли', '22200000'),
#   ('С салона', 'True'),
#   ('Временная зона', '+04'),
#   ('Пробег', '0'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'Maybach GLS')],
#  [('Цвет', '#0000CC'),
#   ('Количество владельцев', '2'),
#   ('Год', '2016'),
#   ('Рубли', '3820000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '57000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLC Coupe')],
#  [('Цвет', '#0000CC'),
#   ('Год', '2022'),
#   ('Рубли', '5080000'),
#   ('С салона', 'True'),
#   ('Временная зона', '+04'),
#   ('Пробег', '0'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLC')],
#  [('Цвет', '#FAFBFB'),
#   ('Количество владельцев', '2'),
#   ('Год', '2014'),
#   ('Рубли', '2920000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '181000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Объем багажника', '680'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GL-Класс')],
#  [('Цвет', '#040001'),
#   ('Количество владельцев', '3'),
#   ('Год', '2009'),
#   ('Рубли', '1160000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '269000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'E-Класс')],
#  [('Цвет', '#FAFBFB'),
#   ('Год', '2021'),
#   ('Рубли', '4660000'),
#   ('С салона', 'True'),
#   ('Временная зона', '+04'),
#   ('Пробег', '0'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Объем багажника', '455'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'C-Класс')],
#  [('Цвет', '#FAFBFB'),
#   ('Год', '2021'),
#   ('Рубли', '5540000'),
#   ('С салона', 'True'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '0'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Объем багажника', '540'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'E-Класс')],
#  [('Лицензия', '******|790'),
#   ('Цвет', '#97948F'),
#   ('Количество владельцев', '4'),
#   ('Год', '2005'),
#   ('Рубли', '780000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '285000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'M-Класс')],
#  [('Цвет', '#FAFBFB'),
#   ('Количество владельцев', '4'),
#   ('Год', '2016'),
#   ('Рубли', '3290000'),
#   ('С салона', 'True'),
#   ('Временная зона', '+04'),
#   ('Пробег', '126000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Объем багажника', '520'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'CLS')],
#  [('Лицензия', '******|152'),
#   ('Цвет', '#97948F'),
#   ('Количество владельцев', '4'),
#   ('Год', '1989'),
#   ('Рубли', '170000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '370000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', '190 (W201)')],
#  [('Цвет', '#040001'),
#   ('Количество владельцев', '3'),
#   ('Год', '2016'),
#   ('Рубли', '4480000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '112000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'S-Класс')],
#  [('Цвет', '#97948F'),
#   ('Количество владельцев', '1'),
#   ('Год', '2019'),
#   ('Рубли', '15020000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '40000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'G-Класс')],
#  [('Лицензия', '******|12'),
#   ('Цвет', '#040001'),
#   ('Количество владельцев', '1'),
#   ('Год', '2017'),
#   ('Рубли', '4320000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '91000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLC')],
#  [('Цвет', '#FAFBFB'),
#   ('Год', '2021'),
#   ('Рубли', '11380000'),
#   ('С салона', 'True'),
#   ('Временная зона', '+04'),
#   ('Пробег', '0'),
#   ('Тип автомобиля', 'LIFTBACK'),
#   ('Количество дверей', '5'),
#   ('Объем багажника', '456'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'AMG GT')],
#  [('Цвет', '#97948F'),
#   ('Год', '2021'),
#   ('Рубли', '4830000'),
#   ('С салона', 'True'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '0'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLB')],
#  [('Цвет', '#040001'),
#   ('Год', '2021'),
#   ('Рубли', '6000000'),
#   ('С салона', 'True'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '0'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Объем багажника', '540'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'E-Класс')],
#  [('Цвет', '#97948F'),
#   ('Год', '2021'),
#   ('Рубли', '5550000'),
#   ('С салона', 'True'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '0'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLC')],
#  [('Цвет', '#040001'),
#   ('Количество владельцев', '1'),
#   ('Год', '2021'),
#   ('Рубли', '5780000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '13000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLC Coupe')],
#  [('Цвет', '#040001'),
#   ('Количество владельцев', '2'),
#   ('Год', '2020'),
#   ('Рубли', '14690000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '22000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'G-Класс')],
#  [('Цвет', '#040001'),
#   ('Количество владельцев', '1'),
#   ('Год', '2019'),
#   ('Рубли', '4150000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '34000'),
#   ('Тип автомобиля', 'MINIVAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'Vito')],
#  [('Цвет', '#040001'),
#   ('Количество владельцев', '1'),
#   ('Год', '2016'),
#   ('Рубли', '2190000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '125000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLA')],
#  [('Цвет', '#97948F'),
#   ('Год', '2021'),
#   ('Рубли', '5240000'),
#   ('С салона', 'True'),
#   ('Временная зона', '+04'),
#   ('Пробег', '0'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Объем багажника', '540'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'E-Класс')],
#  [('Лицензия', '******|18'),
#   ('Цвет', '#FAFBFB'),
#   ('Количество владельцев', '4'),
#   ('Год', '2009'),
#   ('Рубли', '1190000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '213000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'E-Класс')],
#  [('Цвет', '#97948F'),
#   ('Год', '2021'),
#   ('Рубли', '5050000'),
#   ('С салона', 'True'),
#   ('Временная зона', '+04'),
#   ('Пробег', '0'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLB')],
#  [('Цвет', '#040001'),
#   ('Год', '2021'),
#   ('Рубли', '5850000'),
#   ('С салона', 'True'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '0'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Объем багажника', '540'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'E-Класс')],
#  [('Цвет', '#0000CC'),
#   ('Количество владельцев', '2'),
#   ('Год', '2020'),
#   ('Рубли', '7260000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '19000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLE')],
#  [('Лицензия', '******|73'),
#   ('Цвет', '#040001'),
#   ('Количество владельцев', '4'),
#   ('Год', '2016'),
#   ('Рубли', '2600000'),
# ...
#   ('Количество владельцев', '4'),
#   ('Год', '2009'),
#   ('Рубли', '870000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '197000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'C-Класс')],
#  [('Цвет', '#040001'),
#   ('Количество владельцев', '1'),
#   ('Год', '2020'),
#   ('Рубли', '8980000'),
#   ('С салона', 'True'),
#   ('Временная зона', '+04'),
#   ('Пробег', '11000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLE')],
#  [('Цвет', '#FAFBFB'),
#   ('Количество владельцев', '1'),
#   ('Год', '2021'),
#   ('Рубли', '5290000'),
#   ('С салона', 'True'),
#   ('Временная зона', '+04'),
#   ('Пробег', '5000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLC')],
#  [('Цвет', '#FAFBFB'),
#   ('Количество владельцев', '4'),
#   ('Год', '2018'),
#   ('Рубли', '2490000'),
#   ('С салона', 'True'),
#   ('Временная зона', '+04'),
#   ('Пробег', '43000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'C-Класс')],
#  [('Цвет', '#040001'),
#   ('Количество владельцев', '1'),
#   ('Год', '2021'),
#   ('Рубли', '16520000'),
#   ('С салона', 'True'),
#   ('Временная зона', '+04'),
#   ('Пробег', '2000'),
#   ('Тип автомобиля', 'LIFTBACK'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'AMG GT')],
#  [('Цвет', '#0000CC'),
#   ('Количество владельцев', '2'),
#   ('Год', '2017'),
#   ('Рубли', '4780000'),
#   ('С салона', 'True'),
#   ('Временная зона', '+04'),
#   ('Пробег', '112000'),
#   ('Тип автомобиля', 'MINIVAN'),
#   ('Количество дверей', '5'),
#   ('Объем багажника', '1030'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'V-Класс')],
#  [('Цвет', '#FAFBFB'),
#   ('Количество владельцев', '2'),
#   ('Год', '2017'),
#   ('Рубли', '5310000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '160000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Объем багажника', '650'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLE Coupe')],
#  [('Цвет', '#97948F'),
#   ('Год', '2021'),
#   ('Рубли', '5420000'),
#   ('С салона', 'True'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '0'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLC')],
#  [('Цвет', '#0000CC'),
#   ('Количество владельцев', '2'),
#   ('Год', '2012'),
#   ('Рубли', '2110000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '68000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'E-Класс')],
#  [('Цвет', '#040001'),
#   ('Количество владельцев', '2'),
#   ('Год', '2019'),
#   ('Рубли', '8620000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '19000'),
#   ('Тип автомобиля', 'PICKUP_TWO'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'X-Класс')],
#  [('Цвет', '#97948F'),
#   ('Количество владельцев', '1'),
#   ('Год', '2017'),
#   ('Рубли', '7830000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '68000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Объем багажника', '510'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'S-Класс')],
#  [('Лицензия', '******|116'),
#   ('Цвет', '#040001'),
#   ('Количество владельцев', '4'),
#   ('Год', '2007'),
#   ('Рубли', '910000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '235000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'S-Класс')],
#  [('Лицензия', '******|18'),
#   ('Цвет', '#040001'),
#   ('Количество владельцев', '4'),
#   ('Год', '2010'),
#   ('Рубли', '1360000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '174000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'S-Класс')],
#  [('Лицензия', '******|716'),
#   ('Цвет', '#97948F'),
#   ('Количество владельцев', '1'),
#   ('Год', '2019'),
#   ('Рубли', '4310000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '28000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'A-Класс AMG')],
#  [('Лицензия', '******|716'),
#   ('Цвет', '#FAFBFB'),
#   ('Количество владельцев', '1'),
#   ('Год', '2020'),
#   ('Рубли', '7120000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '15000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLE')],
#  [('Лицензия', '******|156'),
#   ('Цвет', '#040001'),
#   ('Количество владельцев', '4'),
#   ('Год', '2011'),
#   ('Рубли', '1520000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '137000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'E-Класс')],
#  [('Цвет', '#040001'),
#   ('Количество владельцев', '4'),
#   ('Год', '2003'),
#   ('Рубли', '380000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '375000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'C-Класс')],
#  [('Цвет', '#040001'),
#   ('Количество владельцев', '4'),
#   ('Год', '2010'),
#   ('Рубли', '1220000'),
#   ('С салона', 'True'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '199000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'S-Класс')],
#  [('Лицензия', '******|199'),
#   ('Цвет', '#97948F'),
#   ('Количество владельцев', '3'),
#   ('Год', '2005'),
#   ('Рубли', '880000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '195000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'S-Класс')],
#  [('Цвет', '#040001'),
#   ('Количество владельцев', '2'),
#   ('Год', '2020'),
#   ('Рубли', '11690000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '8000'),
#   ('Тип автомобиля', 'LIFTBACK'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'AMG GT')],
#  [('Цвет', '#0000CC'),
#   ('Количество владельцев', '1'),
#   ('Год', '2019'),
#   ('Рубли', '4210000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '27000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'E-Класс')],
#  [('Цвет', '#0000CC'),
#   ('Количество владельцев', '3'),
#   ('Год', '2017'),
#   ('Рубли', '4620000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '67000'),
#   ('Тип автомобиля', 'COUPE'),
#   ('Количество дверей', '2'),
#   ('Объем багажника', '425'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'E-Класс')],
#  [('Цвет', '#FAFBFB'),
#   ('Количество владельцев', '2'),
#   ('Год', '2013'),
#   ('Рубли', '3030000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '126000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'M-Класс')],
#  [('Цвет', '#CACECB'),
#   ('Количество владельцев', '4'),
#   ('Год', '2001'),
#   ('Рубли', '490000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '318000'),
#   ('Тип автомобиля', 'HATCHBACK_3_DOORS'),
#   ('Количество дверей', '3'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'C-Класс')],
#  [('Лицензия', '******|163'),
#   ('Цвет', '#FAFBFB'),
#   ('Количество владельцев', '3'),
#   ('Год', '2015'),
#   ('Рубли', '4790000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '120000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Объем багажника', '650'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLE Coupe AMG')],
#  [('Лицензия', '******|77'),
#   ('Цвет', '#040001'),
#   ('Количество владельцев', '1'),
#   ('Год', '2021'),
#   ('Рубли', '9360000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '5000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Объем багажника', '655'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLE Coupe')],
#  [('Цвет', '#CACECB'),
#   ('Количество владельцев', '2'),
#   ('Год', '2013'),
#   ('Рубли', '2210000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '102000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLK-Класс')],
#  [('Лицензия', '******|763'),
#   ('Цвет', '#97948F'),
#   ('Количество владельцев', '2'),
#   ('Год', '2018'),
#   ('Рубли', '6100000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '101000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'CLS')],
#  [('Цвет', '#040001'),
#   ('Количество владельцев', '4'),
#   ('Год', '2006'),
#   ('Рубли', '640000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '266000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'C-Класс')],
#  [('Лицензия', '******|164'),
#   ('Цвет', '#FAFBFB'),
#   ('Количество владельцев', '2'),
#   ('Год', '2018'),
#   ('Рубли', '2210000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '52000'),
#   ('Тип автомобиля', 'HATCHBACK_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Объем багажника', '370'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'A-Класс')],
#  [('Цвет', '#0000CC'),
#   ('Количество владельцев', '1'),
#   ('Год', '2020'),
#   ('Рубли', '3990000'),
#   ('С салона', 'True'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '10000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Объем багажника', '570'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLB')],
#  [('Цвет', '#0000CC'),
#   ('Количество владельцев', '2'),
#   ('Год', '2016'),
#   ('Рубли', '6440000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '52000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Объем багажника', '510'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'S-Класс AMG')],
#  [('Цвет', '#040001'),
#   ('Год', '2021'),
#   ('Рубли', '13070000'),
#   ('С салона', 'True'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '0'),
#   ('Тип автомобиля', 'LIFTBACK'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'AMG GT')],
#  [('Цвет', '#040001'),
#   ('Количество владельцев', '3'),
#   ('Год', '2012'),
#   ('Рубли', '1350000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '150000'),
#   ('Тип автомобиля', 'COUPE_HARDTOP'),
#   ('Количество дверей', '2'),
#   ('Объем багажника', '450'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'E-Класс')],
#  [('Цвет', '#200204'),
#   ('Количество владельцев', '4'),
#   ('Год', '2013'),
#   ('Рубли', '1160000'),
#   ('С салона', 'True'),
#   ('Временная зона', '+04'),
#   ('Пробег', '89000'),
#   ('Тип автомобиля', 'HATCHBACK_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'B-Класс')],
#  [('Лицензия', '******|116'),
#   ('Цвет', '#040001'),
#   ('Количество владельцев', '3'),
#   ('Год', '2015'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '73000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GL-Класс AMG')],
#  [('Лицензия', '******|763'),
#   ('Цвет', '#97948F'),
#   ('Количество владельцев', '2'),
#   ('Год', '2016'),
#   ('Рубли', '2870000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '35000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Объем багажника', '421'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLA')],
#  [('Цвет', '#FAFBFB'),
#   ('Количество владельцев', '4'),
#   ('Год', '2015'),
#   ('Рубли', '3470000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '164000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GL-Класс')],
#  [('Цвет', '#97948F'),
#   ('Количество владельцев', '4'),
#   ('Год', '2009'),
#   ('Рубли', '870000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '197000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'C-Класс')],
#  [('Цвет', '#040001'),
#   ('Количество владельцев', '1'),
#   ('Год', '2020'),
#   ('Рубли', '8980000'),
#   ('С салона', 'True'),
#   ('Временная зона', '+04'),
#   ('Пробег', '11000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLE')],
#  [('Цвет', '#FAFBFB'),
#   ('Количество владельцев', '1'),
#   ('Год', '2021'),
#   ('Рубли', '5290000'),
#   ('С салона', 'True'),
#   ('Временная зона', '+04'),
#   ('Пробег', '5000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLC')],
#  [('Цвет', '#FAFBFB'),
#   ('Количество владельцев', '4'),
#   ('Год', '2018'),
#   ('Рубли', '2490000'),
#   ('С салона', 'True'),
#   ('Временная зона', '+04'),
#   ('Пробег', '43000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'C-Класс')],
#  [('Цвет', '#040001'),
#   ('Количество владельцев', '1'),
#   ('Год', '2021'),
#   ('Рубли', '16520000'),
#   ('С салона', 'True'),
#   ('Временная зона', '+04'),
#   ('Пробег', '2000'),
#   ('Тип автомобиля', 'LIFTBACK'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'AMG GT')],
#  [('Цвет', '#0000CC'),
#   ('Количество владельцев', '2'),
#   ('Год', '2017'),
#   ('Рубли', '4780000'),
#   ('С салона', 'True'),
#   ('Временная зона', '+04'),
#   ('Пробег', '112000'),
#   ('Тип автомобиля', 'MINIVAN'),
#   ('Количество дверей', '5'),
#   ('Объем багажника', '1030'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'V-Класс')],
#  [('Цвет', '#FAFBFB'),
#   ('Количество владельцев', '2'),
#   ('Год', '2017'),
#   ('Рубли', '5310000'),
#   ('С салона', 'False'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '160000'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Объем багажника', '650'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLE Coupe')],
#  [('Цвет', '#97948F'),
#   ('Год', '2021'),
#   ('Рубли', '5420000'),
#   ('С салона', 'True'),
#   ('Временная зона', 'MSK'),
#   ('Пробег', '0'),
#   ('Тип автомобиля', 'ALLROAD_5_DOORS'),
#   ('Количество дверей', '5'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'GLC')],
#  [('Цвет', '#0000CC'),
#   ('Количество владельцев', '2'),
#   ('Год', '2012'),
#   ('Рубли', '2110000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '68000'),
#   ('Тип автомобиля', 'SEDAN'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'E-Класс')],
#  [('Цвет', '#040001'),
#   ('Количество владельцев', '2'),
#   ('Год', '2019'),
#   ('Рубли', '8620000'),
#   ('С салона', 'False'),
#   ('Временная зона', '+04'),
#   ('Пробег', '19000'),
#   ('Тип автомобиля', 'PICKUP_TWO'),
#   ('Количество дверей', '4'),
#   ('Марка автомобиля', 'Mercedes-Benz'),
#   ('Модель автомобиля', 'X-Класс')],
#  ...]

# %%
data = pd.DataFrame(columns=signs)

for label in labels:
    labeldict = {}
    for i in range(len(label)):
        labeldict[label[i][0]] = label[i][1]
    data = data.append(labeldict, ignore_index=True)

# %%
data.head()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1724 entries, 0 to 1723
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Рубли                  1695 non-null   object
#  1   Пробег                 1724 non-null   object
#  2   Количество дверей      1724 non-null   object
#  3   Объем багажника        481 non-null    object
#  4   Количество владельцев  1537 non-null   object
#  5   Год                    1724 non-null   object
#  6   Лицензия               732 non-null    object
#  7   С салона               1724 non-null   object
#  8   Цвет                   1724 non-null   object
#  9   Временная зона         1724 non-null   object
#  10  Марка автомобиля       1724 non-null   object
#  11  Модель автомобиля      1724 non-null   object
#  12  Тип автомобиля         1724 non-null   object
# dtypes: object(13)
# memory usage: 175.2+ KB

# %% [markdown]
# ## Отбор признаков
# - Уберем признак "Лицензия", так как более половины значений в нем - пропущенные.
# - Уберем те автомобили, у которых не известна цена в рублях (позже можно просто будет сделать конвертации между долларами/евро/рублями).
# - Пустые значения колонки 'Пробег' заполним медианным значением.
# - Для пустых ячеек признака "Количество владельцев" поставим хотя бы 1.
# - Создадим три списка признаков, соответствующие их группам: вещественные, целочисленные и категориальные.

# %%
data = data[data['Рубли'].notna()]
data = data.drop(['Лицензия'], axis=1)
data['Количество владельцев'].fillna(1, inplace=True)
data['Объем багажника'].fillna(data['Объем багажника'].notnull().astype('int').mean(), inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1695 entries, 0 to 1723
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Рубли                  1695 non-null   object
#  1   Пробег                 1695 non-null   object
#  2   Количество дверей      1695 non-null   object
#  3   Объем багажника        1695 non-null   object
#  4   Количество владельцев  1695 non-null   object
#  5   Год                    1695 non-null   object
#  6   С салона               1695 non-null   object
#  7   Цвет                   1695 non-null   object
#  8   Временная зона         1695 non-null   object
#  9   Марка автомобиля       1695 non-null   object
#  10  Модель автомобиля      1695 non-null   object
#  11  Тип автомобиля         1695 non-null   object
# dtypes: object(12)
# memory usage: 172.1+ KB

# %%
real_features = ['Пробег', 'Рубли']
discrete_features = ['Количество дверей', 'Объем багажника', 'Количество владельцев', 'Год']
cat_features = data.columns.drop(real_features).drop(discrete_features).tolist()

# %% [markdown]
# Первичный анализ:

# %%
#data[discrete_features].describe()
data[real_features] = data[real_features].astype('int')
data[real_features].info()
real_hist = data[real_features].hist(bins=100, figsize=(20,5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1695 entries, 0 to 1723
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Пробег  1695 non-null   int64
#  1   Рубли   1695 non-null   int64
# dtypes: int64(2)
# memory usage: 39.7 KB

# %%
data[discrete_features] = data[discrete_features].astype('int')
data[discrete_features].info()
discrete_hist = data[discrete_features].hist(bins=50, figsize=(20,5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1695 entries, 0 to 1723
# Data columns (total 4 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Количество дверей      1695 non-null   int64
#  1   Объем багажника        1695 non-null   int64
#  2   Количество владельцев  1695 non-null   int64
#  3   Год                    1695 non-null   int64
# dtypes: int64(4)
# memory usage: 66.2 KB

# %%
def count_uniques(lst):
    counts = {}
    for i in range(len(lst)):
        if lst[i] in counts:
            counts[lst[i]] += 1
        else:
            counts[lst[i]] = 1
    return counts.keys(), counts.values()

# %%
fig, axes = plt.subplots(len(cat_features)-2, 1, figsize=(15, 20))
for i in range(len(cat_features)):
    if cat_features[i] == 'Модель автомобиля' or cat_features[i] == 'Тип автомобиля':
        labels, values = count_uniques(list(data[cat_features[i]]))
        position = np.arange(len(labels))
        fig, ax = plt.subplots()
        ax.barh(position, values)
        ax.set_yticks(position)
        labels = ax.set_yticklabels(labels,
                   verticalalignment =  'center')    #  Вертикальное выравнивание     
        fig.set_figwidth(10)
        fig.set_figheight(10)
    else:
        seaborn.countplot(x=cat_features[i], data=data, ax=axes[int(i % (len(cat_features)-2))])

# %% [markdown]
# Видим, что среди категориальных признаков тоже есть выбросы. Это может в дальнейшем осложнить, например, классификацию.
# Скорее всего, если мы будем использовать DBScan, эти объекты автоматически отнесутся к выбросам, но все же не стоит о них забывать.
#
# P.S. поскольку парсили мы автомобили конкретно по марке Mерседес, то и признак этот имеет всего одно значение, изменив парсер, **в дальнейшем мы конечно же можем сравнивать автомобили разных марок**.
# Можно так же, например, попробовать предсказывать марки автомобилей по имеющимся параметрам бинарным классификатором (то же самое можно делать и для других бинарных категорий).

# %% [markdown]
# # Проверим гипотезу о влиянии года машины на цену

# %% [markdown]
# Исключительно ради примера проверим, насколько статистически значимая разница (на уровне p-value = 0.05) между ценой автомобилей до 2000 года (включительно) и после.

# %%
x = data['Год']
y = data['Рубли']

# %%
plt.scatter(x, y)
plt.show()

# %% [markdown]
# Уже сейчас заметна зависимость в данных.
#
# Видим выброс 1939 года, посмотрим на него внимательнее:

# %%
data.loc[data['Год'] == 1939]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Рубли</th>
#       <th>Пробег</th>
#       <th>Количество дверей</th>
#       <th>Объем багажника</th>
#       <th>Количество владельцев</th>
#       <th>Год</th>
#       <th>С салона</th>
#       <th>Цвет</th>
#       <th>Временная зона</th>
#       <th>Марка автомобиля</th>
#       <th>Модель автомобиля</th>
#       <th>Тип автомобиля</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>644</th>
#       <td>5430000</td>
#       <td>1000</td>
#       <td>2</td>
#       <td>0</td>
#       <td>1</td>
#       <td>1939</td>
#       <td>False</td>
#       <td>#FAFBFB</td>
#       <td>MSK</td>
#       <td>Mercedes-Benz</td>
#       <td>W142</td>
#       <td>CABRIO</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Удалим этот объект, т.к. он является сильной аномалией по сравнению с остальными.

# %%
data = data.loc[data['Год'] != 1939]
#data.info()

# %%
x = data['Год']
y = data['Рубли']

# %%
plt.scatter(x, y)
plt.show()

# %% [markdown]
# Интересен тот факт, что автомобили среди объявления Mersedes начинают появляться с ~80-х годов выпуска - тогда наладились массовое производство автомобилей и их поставки в Россию.

# %%
# stand_1 = preprocessing.StandardScaler()
# stand_2 = preprocessing.MaxAbsScaler()
stand_3 = preprocessing.MinMaxScaler()

# %%
# Параметры стандартизации:
stand_3.fit(data[real_features+discrete_features])

# Преобразуем данные, получим X - матрицу класса numpy.ndarray.
X = stand_3.transform(data[real_features+discrete_features]) 

# Преобразуем X в объект класса pandas.DataFrame:
X = pd.DataFrame(X, index=data[real_features+discrete_features].index, columns=data[real_features+discrete_features].columns)

# %%
x = X.loc[data['Год'] > 2000]['Рубли']
y = X.loc[data['Год'] <= 2000]['Рубли']
x.name, y.name = 'Year>2000', 'Year<=2000'

# %%
from statsmodels.stats.weightstats import zconfint
print('95% confidence interval for the ', x.name, ' mean: [%f, %f]' % zconfint(x))
print('95% confidence interval for the ', y.name, ' mean: [%f, %f]' % zconfint(y))
# Out:
# 95% confidence interval for the  Year>2000  mean: [0.156696, 0.171303]
# 95% confidence interval for the  Year<=2000  mean: [0.011507, 0.027161]

# %% [markdown]
# Интервалы не пересекаются, это уже многое говорит о разнице значений в данных, однако проверим все же до конца:

# %%
def two_histograms(x, y):
    x.hist(alpha=0.5, weights=[1./len(x)]*len(x))
    y.hist(alpha=0.5, weights=[1./len(y)]*len(y))
    plt.axvline(x.mean(), color='red', alpha=0.8, linestyle='dashed')
    plt.axvline(y.mean(), color='blue', alpha=0.8, linestyle='dashed')
    plt.legend([x.name, y.name])

# %%
import numpy as np
two_histograms(x, y)

# %% [markdown]
# Выборки явно не распределены нормально - видны правые хвосты (можно конечно в таком случае посмотреть на логарифм).
# В таком случае не будем применять критерий Стьюдента и воспользуемся сразу Манна-Уитни:

# %%
res = stats.mannwhitneyu(x, y, method="asymptotic")[1]
print('p-value: ', res)
# Out:
# p-value:  3.0150238326482374e-34

# %% [markdown]
# Нулевая гипотеза о равенстве средних выборок уверенно отвергается. Можно сделать **логический ожидаемый вывод о том, что с увеличением года выпуска(уменьшением возраста машины), цена увеличивается**.
#
# Сделаем ради примера проверку еще и перестановочным критерием.

# %%
def permutation_t_stat_ind(sample1, sample2):
    return np.mean(sample1) - np.mean(sample2)

# %%
def get_random_combinations(n1, n2, max_combinations):
    index = list(range(n1 + n2))
    indices = set([tuple(index)])
    for i in range(max_combinations - 1):
        np.random.shuffle(index)
        indices.add(tuple(index))
    return [(index[:n1], index[n1:]) for index in indices]

# %%
import itertools
def permutation_zero_dist_ind(sample1, sample2, max_combinations = None):
    joined_sample = np.hstack((sample1, sample2))
    n1 = len(sample1)
    n = len(joined_sample)
    
    if max_combinations:
        indices = get_random_combinations(n1, len(sample2), max_combinations)
    else:
        indices = [(list(index), filter(lambda i: i not in index, range(n))) \
                    for index in itertools.combinations(range(n), n1)]
    
    distr = [joined_sample[list(i[0])].mean() - joined_sample[list(i[1])].mean() \
             for i in indices]
    return distr

# %%
plt.hist(permutation_zero_dist_ind(x, y, max_combinations = 10000))
plt.show()

# %%
def permutation_test(sample, mean, max_permutations = None, alternative = 'two-sided'):
    if alternative not in ('two-sided', 'less', 'greater'):
        raise ValueError("alternative not recognized\n"
                         "should be 'two-sided', 'less' or 'greater'")
    
    t_stat = permutation_t_stat_ind(sample, mean)
    
    zero_distr = permutation_zero_dist_ind(sample, mean, max_permutations)
    
    if alternative == 'two-sided':
        return sum([1. if abs(x) >= abs(t_stat) else 0. for x in zero_distr]) / len(zero_distr)
    
    if alternative == 'less':
        return sum([1. if x <= t_stat else 0. for x in zero_distr]) / len(zero_distr)

    if alternative == 'greater':
        return sum([1. if x >= t_stat else 0. for x in zero_distr]) / len(zero_distr)

# %%
print ("p-value: %f" % permutation_test(x, y, max_permutations = 10000))
# Out:
# p-value: 0.000100

# %% [markdown]
# Нулевая гипотеза снова отвергается - **есть статистически значимая зависимость между годом выпуска и ценой**.

# %% [markdown]
# # Попробуем сделать простенькую кластеризацию KMeans

# %%
from sklearn.cluster import KMeans

# %%
# Параметры стандартизации:
stand_3.fit(data[real_features + discrete_features])

# Преобразуем данные, получаем матрицу класса numpy.ndarray:
X = stand_3.transform(data[real_features + discrete_features]) 

# Преобразуем её в объект класса pandas.DataFrame:
X = pd.DataFrame(X, index=data[real_features + discrete_features].index, 
                 columns=data[real_features + discrete_features].columns)

K = range(1, 11)
models = [KMeans(n_clusters=k, random_state=42).fit(X) for k in K]
dist = [model.inertia_ for model in models]

# Строим график каменистая осыпь:
plt.plot(K, dist, marker='o')
plt.xlabel('Число кластеров')
plt.ylabel('Сумма квадратов расстояний')
plt.title('Каменистая осыпь. Ищем оптимальное k')
plt.show()

# %% [markdown]
# Исходя из графика Каменистой осыпи, наиболее разумным кажется разделение датасета на 3-4 кластера. Попробуем 4:

# %%
model = KMeans(n_clusters=4, random_state=42)
model.fit(X)

#  К таблице добавим марки кластеров:
X['cluster'] = model.labels_
X.groupby('cluster').mean()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Пробег</th>
#       <th>Рубли</th>
#       <th>Количество дверей</th>
#       <th>Объем багажника</th>
#       <th>Количество владельцев</th>
#       <th>Год</th>
#     </tr>
#     <tr>
#       <th>cluster</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.329684</td>
#       <td>0.046109</td>
#       <td>0.735690</td>
#       <td>0.025491</td>
#       <td>0.930976</td>
#       <td>0.663340</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.072880</td>
#       <td>0.249132</td>
#       <td>0.883041</td>
#       <td>0.000000</td>
#       <td>0.132908</td>
#       <td>0.903395</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.091468</td>
#       <td>0.197906</td>
#       <td>0.907986</td>
#       <td>0.560424</td>
#       <td>0.216146</td>
#       <td>0.903832</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.196050</td>
#       <td>0.095877</td>
#       <td>0.000000</td>
#       <td>0.314716</td>
#       <td>0.629213</td>
#       <td>0.790530</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
X.groupby('cluster').size()

# %% [markdown]
# Попробуем приближенно проинтерпретировать полученную кластеризацию.
# - **1-й кластер** - сюда попали наиболее дорогие машины: мы можем видеть, что средний год таких машин тоже достаточно высок (т.е. скорее всего они преимущественно новые), параметры пробега и количества владельцев низкие, при этом это судя по всему машины без багажника
# - **2-й кластер** - сюда тоже попали достаточно дорогие машины, с небольшим пробегом и количеством владельцев, свежим годом, но при этом достаточно большим багажником
# - **3-й кластер** - более дешевые и старые машины, обладают бОльшим пробегом, по сравнению с предыдущими двумя
# - **0-й кластер** - машины с самым низким средним показателем цены и года, набольшим пробегом
#
# В целом данные логически интерпретируются. Для более точной кластеризации **следует учитывать наличие выбросов по целочисленным параметрам.**

# %% [markdown]
# # Попробуем сделать простенькую кластеризацию DBScan

# %%
from sklearn.cluster import DBSCAN

# %%
from sklearn import preprocessing

stand_1 = preprocessing.StandardScaler()
# stand_2 = preprocessing.MaxAbsScaler()
# stand_3 = preprocessing.MinMaxScaler()

X2 = X.drop(['cluster'], axis=1)

# Параметры стандартизации:
stand_1.fit(data[real_features + discrete_features])

# Преобразуем данные, получаем матрицу класса numpy.ndarray:
X2 = stand_1.transform(data[real_features + discrete_features]) 

# Преобразуем её в объект класса pandas.DataFrame:
X2 = pd.DataFrame(X2, index=data[real_features + discrete_features].index, 
                 columns=data[real_features + discrete_features].columns)

# %%
#  Создадим объект DBSCAN, зададим значения параметров:
dbscan = DBSCAN(eps=1.31, metric='euclidean', min_samples=3)

#  Обучим модель DBSCAN:
dbscan.fit(X2)

# В какой кластер попало наблюдение - np-массив номеров кластеров:
dbscan.labels_

# Таблица частот: 
unique, counts = np.unique(dbscan.labels_, return_counts=True)
print(np.asarray((unique, counts)).T)
# Out:
# [[  -1   17]
#  [   0 1564]
#  [   1   64]
#  [   2   29]
#  [   3   20]]

# %% [markdown]
# P.S. Можно еще поподбирать параметры eps и min_samples для получения более 'приятной' классификации. Можно также почистить данные от очевидных выбросов или попробовать обобщить некоторые категории.

# %% [markdown]
# ## t-SNE

# %%
from sklearn.manifold import TSNE
import matplotlib.cm as cm # - цветовые схемы для графиков

# %%
data_subset = X.drop(['cluster'], axis=1)
response_subset = X['cluster']

# %%
import warnings
warnings.filterwarnings("ignore")

method = TSNE(random_state=321)
tsne_representation = method.fit_transform(data_subset)

# %%
colors = cm.rainbow(np.linspace(0, 1, len(set(response_subset))))
for y, color in zip(set(response_subset), colors):
    plt.scatter(tsne_representation[response_subset.values==y, 0],
                tsne_representation[response_subset.values==y, 1], c=color.reshape(1,-1), alpha=0.5, label=str(y))
plt.legend()

# %% [markdown]
# Можно сделать выводы, что простенький Kmeans действительно выделил классы не слишком плохо.
#
# Если уделить больше времени анализу, выбору подходящей модели и параметров для нее, можно сделать кластеризацию лучше.
